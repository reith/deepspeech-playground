# %%
import os
# use CPU or GPU
os.environ['KERAS_BACKEND'] = 'theano'
#os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['THEANO_FLAGS'] = 'device=cuda0'

# %%
import keras
import numpy as np
# Out:
# Using Theano backend.
# Using cuDNN version 5110 on context None
# Mapped name None to device cuda0: GeForce GTX 1080 Ti (0000:02:00.0)

# %% [markdown]
# ### Data and weight loaders

# %%
from glob import glob
from random import Random
import json

rng = Random(42)

# %%
import kenlm
import beamsearch
reload(beamsearch)
from utils import argmax_decode, word_error_rate, for_tf_or_th
from beamsearch import beam_decode, beam_decode_u

lm = kenlm.Model('data/lm/lm.binary')

def iterate_weights(model_path):
    """Iterate over saved model weights"""
    for model_weight in glob(os.path.join(model_path, '') + '*.h5'):
        yield model_weight

def pick_sample_files(desc_file, count, min_duration, max_duration):
    metadata = []
    with open(desc_file) as f:
        for line in f:
            metadata.append(json.loads(line))
    legitimates = [ sample for sample in metadata if min_duration <= sample['duration'] <= max_duration ]
    rng.shuffle(legitimates)
    return legitimates[:count]

def test_generator(datagen, test_samples, batch_size=64, normalize=True):
    global in_
    texts = [s['text'] for s in test_samples]
    durations = [s['duration'] for s in test_samples]
    paths = [s['key'] for s in test_samples]
    features = [datagen.featurize(p) for p in paths]
    if normalize:
        features = [datagen.normalize(f) for f in features]

    for i in range( np.ceil(len(features) / float(batch_size)).astype(int) ):
        batch_durations = durations[i*batch_size: (i+1)*batch_size]
        batch_features = features[i*batch_size: (i+1)*batch_size]
        batch_texts = texts[i*batch_size: (i+1)*batch_size]
        batch_paths = paths[i*batch_size: (i+1)*batch_size]
        max_length = max([f.shape[0] for f in batch_features])
        batch_array = np.zeros((len(batch_features), max_length, features[0].shape[1]), dtype='float32')
        for fi in range(len(batch_features)):
            batch_array[fi, :batch_features[fi].shape[0], :] = batch_features[fi]
        yield {'x': batch_array, 'y': batch_texts, 'path': batch_paths, 'duration': batch_durations}

def best_lm_alternative(true_sentence, wer, predictions, verbose=False):
    """ predictions is a list of tuples which first denote sentence and next is It's probablity
    """
    best, best_score = None, np.finfo('float32').min
    for s, p in predictions:
        lm_score = lm.score(s)
        if lm_score > best_score:
            best, best_score = s, lm_score
    if best == predictions[0][0]:
        if verbose:
            print "langauge model didn't change prediction"
        best_wer = wer
    else:
        best_wer = word_error_rate([true_sentence], [best], decoded=True)[0]
        if verbose:
            print "langauge model changed prediction, WER changed from {old_wer} to {new_wer}".format(
                old_wer = wer, new_wer = best_wer
            )
    return best, best_wer

def evaluate(batch_generator, output_fn, learning_phase=False, use_lm=False, beam_width=12):
    all_nolm_wers, all_lm_wers = [], []
    for batch in batch_generator:
        net_out = output_fn([batch['x'], learning_phase])[0]
        mtp_net_out = for_tf_or_th(net_out, net_out.swapaxes(0, 1))
        pred_texts = [argmax_decode(o) for o in mtp_net_out]
        nolm_wers = word_error_rate(batch['y'], pred_texts, True)
        all_nolm_wers.append(nolm_wers)
        
        if use_lm:
            alt_beam_preds = lambda i: zip(*beam_decode_u(mtp_net_out[i, :, :], beam_width, normalize=True))
            pred_texts, lm_wers = zip(*[best_lm_alternative(batch['y'][i], nolm_wers[i], alt_beam_preds(i))
                                      for i in range(mtp_net_out.shape[0])])
            all_lm_wers.append(np.array(lm_wers))
            all_wers = all_lm_wers
        else:
            all_wers = all_nolm_wers
        
        for i, y in enumerate(batch['y']):
            print 'r:{}\np:{}\n{}: WER: {}, DURATION: {}, PATH: {}'.format(y, pred_texts[i], i, all_wers[-1][i], batch['duration'][i], batch['path'][i])
        print 'batch mean WER: {}'.format(all_wers[-1].mean())
    if use_lm:
        print 'LM WER: {} No LM WER: {}'.format(np.concatenate(all_lm_wers).mean(), np.concatenate(all_nolm_wers).mean())
    else:
        'whole mean WER: {}'.format(np.concatenate(all_wers).mean())
    return mtp_net_out, pred_texts, all_wers, batch['y']

# %% [markdown]
# ### Customize data generator

# %%
test_desc = '/home/reith/deepspeech/ba-dls-deepspeech/descs/test-clean.json'
#test_desc = '/home/reith/deepspeech/ba-dls-deepspeech/descs/test-other.json'
#test_desc = '/home/reith/deepspeech/ba-dls-deepspeech/descs/dev-clean.json'

# %%
from data_generator import DataGenerator
datagen = DataGenerator()

# %%
test_samples = pick_sample_files(test_desc, 1024, 0, 30)

# %% [markdown]
# Normalize by input data

# %%
train_desc = '/home/reith/deepspeech/ba-dls-deepspeech/descs/train-clean-360.json'
datagen.load_train_data(train_desc, 15)
datagen.fit_train(100)

# %% [markdown]
# Or load them

# %%
datagen.reload_norm('860-1000')

# %% [markdown]
# ### Load model

# %% [markdown]
# #### Theano mode

# %% [markdown]
# Load and test weights of a half-phoneme model

# %%
#model_dir = '/home/reith/deepspeech/ba-dls-deepspeech/models/22-cont-23-i9696-lr1e-4-train-360-dur15/'
#model_dir = '/home/reith/deepspeech/ba-dls-deepspeech/models/23-cont-i2494-joingrus-dur15-nobn-lr5e-5/'
model_dir = '/home/reith/deepspeech/ba-dls-deepspeech/models/24-cont-train-860'

# %% [markdown]
# A summary of training procedure:
# - 7 Epochs of dual phoneme-text on train-100 (20)
# - 3 Epochs on train-500 for phoenme fine-tuning (21)
# - 3 Epochs on train-500 for text fine-tuning (22)
# - 2 Epochs on train-360 (23)
# - 2 Epochs on train-360 dropping phoneme branch and and batch normalization (24)

# %% [markdown]
# make half phoneme model

# %%
from model_wrp import HalfPhonemeModelWrapper
model_wrp = HalfPhonemeModelWrapper()
model = model_wrp.compile(nodes=1000, conv_context=5, recur_layers=5)
output_fn = model_wrp.compile_output_fn()
# Out:
# WARNING:model_wrp:ignoring unsuported batchnorm mode of 2 on keras 2
# WARNING:model_wrp:ignoring unsuported batchnorm mode of 2 on keras 2
# WARNING:model_wrp:ignoring unsuported batchnorm mode of 2 on keras 2
# WARNING:model_wrp:ignoring unsuported batchnorm mode of 2 on keras 2
# WARNING:model_wrp:ignoring unsuported batchnorm mode of 2 on keras 2
# model_wrp.py:374: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[Reshape{3..., inputs=/acoustic_...)`
#   self.model = Model(input=acoustic_input, output=[phoneme_out, text_out])

# %% [markdown]
# or gru model

# %%
from model_wrp import GruModelWrapper
model_wrp = GruModelWrapper()
model = model_wrp.compile(nodes=1000, conv_context=5, recur_layers=5, batch_norm=False)
output_fn = model_wrp.compile_output_fn()
# Out:
# model_wrp.py:274: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(29, activation="linear", kernel_initializer="glorot_uniform", name="text_dense")`
#   activation=for_tf_or_th('softmax', 'linear')
# model_wrp.py:278: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[Reshape{3..., inputs=/acoustic_...)`
#   self.model = Model(input=acoustic_input, output=[network_output])

# %%
# model.load_weights(os.path.join(model_dir, 'best-val-weights.h5'))
model.load_weights(os.path.join(model_dir, 'model_19336_weights.h5'))

# %% [markdown]
# #### Tensorflow model

# %% [markdown]
# A summary of training procedure:
# - 3 Epochs of dual phoneme-text on train-100 by dropout of 0.3 and leaky relu factor of 0.05 (40)
# - 5 Epochs on train-100 for phoenme fine-tuning (41)
# - 5 Epochs on train-100 for text fine-tuning (42)
# - 5 Epochs on train-360 (43)
# - 5 Epochs on train-860 dropping phoneme branch and and batch normalization and reduced dropout to 0.1 (44)
# - 20 Epochs on train-860 reduced learning rate down to 5e-5 and for samples up to 20 seconds long (45)

# %%
model_dir = '/home/reith/deepspeech/ba-dls-deepspeech/models/44-cont-45-i14490-dur20-lr5e-5'

# %%
from model_wrp import GruModelWrapper
model_wrp = GruModelWrapper()
model = model_wrp.compile(nodes=1000, conv_context=5, recur_layers=5, dropout=.1, lirelu_alpha=.05, batch_norm=False)
output_fn = model_wrp.compile_output_fn()
# Out:
# model_wrp.py:274: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(29, activation="softmax", kernel_initializer="glorot_uniform", name="text_dense")`
#   activation=for_tf_or_th('softmax', 'linear')
# model_wrp.py:278: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., inputs=Tensor("ac...)`
#   self.model = Model(input=acoustic_input, output=[network_output])

# %%
model.load_weights(os.path.join(model_dir, 'best-val-weights.h5'))

# %%
model.summary()

# %% [markdown]
# ### Evaluate model

# %%
res = evaluate(test_generator(datagen, test_samples, normalize=True), output_fn, use_lm=False)
# Out:
# r:the condition is that i will be permitted to make luther talk american streamline him so to speak because you will never get people whether in or outside the lutheran church actually to read luther unless we make him talk as he would talk today to americans
# p:the condition is that i will be permitted to make lutratalk american stream line him certof speak because you will never get people whether ann aroutside the liter in church actually to read luther an must be mak in talk as he would talk to day to americans
# 0: WER: 0.0778210116732, DURATION: 16.1250625, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3979/2830-3979-0001.wav
# r:we are to hear christ who has been appointed by the father as our divine teacher
# p:we are to hear crist to his benapranted by the father as our divine teacher
# 1: WER: 0.0838709677419, DURATION: 4.88, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0052.wav
# r:in the communities of the western culture this point is at present found among the lower middle class
# p:in the communities of the western culture this point is it present found among the lower middle class
# 2: WER: 0.00990099009901, DURATION: 5.355, PATH: /mnt/ml-data/LibriSpeech/test-clean/3570/5695/3570-5695-0003.wav
# r:she sent me the pages in question before she died
# p:she sent te the pages in question before she died
# 3: WER: 0.0204081632653, DURATION: 2.85, PATH: /mnt/ml-data/LibriSpeech/test-clean/121/127105/121-127105-0010.wav
# r:the queens had taken their seats upon a magnificent dias or platform erected upon the borders of the lake in a theater of wonderful elegance of construction
# p:the queen's had taken their seats upon a magnificent daus or platform a rected upon the borders of the lake it a theatre of wonderful elegance of construction
# 4: WER: 0.0445859872611, DURATION: 10.175, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75946/7127-75946-0014.wav
# r:it has occupied mother a long time to find at the shops the exact shade for her new bonnet
# p:it has occupied mother along time to find at the shops tee exact shade for her new bonnet
# 5: WER: 0.0222222222222, DURATION: 6.04, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29095/4970-29095-0024.wav
# r:thinking of all this i went to sleep
# p:thinking of all this i went to sleep
# 6: WER: 0.0, DURATION: 3.085, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0029.wav
# r:you see loving some one as i love you makes the whole world different
# p:you see loving some one as i love you mix the whole world different
# 7: WER: 0.0510948905109, DURATION: 4.755, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0041.wav
# r:madame quinson besides can answer your enquiries
# p:madame guensong besides cananswer your inquiries
# 8: WER: 0.0927835051546, DURATION: 4.195, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0016.wav
# r:whenever as in these cases the menial service in question has to do directly with the primary leisure employments of fighting and hunting it easily acquires a reflected honorific character
# p:i never as in these cases the menial sericing question has to dedirectly with a prima relisure employments of fighting an hunting it easily acquires a reflected ona refic character
# 9: WER: 0.0760869565217, DURATION: 10.555, PATH: /mnt/ml-data/LibriSpeech/test-clean/3570/5694/3570-5694-0021.wav
# r:silvia was the adoration of france and her talent was the real support of all the comedies which the greatest authors wrote for her especially of the plays of marivaux for without her his comedies would never have gone to posterity
# p:sylvira was the adoration of france and her talent was the real support of all the comedies which the greatest author's wrote for her especially of the plays of mariva for without her his comedies would never have gone to prosterity
# 10: WER: 0.0151187904968, DURATION: 18.54, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0005.wav
# r:alice took up the fan and gloves and as the hall was very hot she kept fanning herself all the time she went on talking dear dear how queer everything is to day
# p:alice took up the fan and gloves and as the hall was very hot she kept fanning herself all the time she went on talking dear dear how queer everything is to day
# 11: WER: 0.0, DURATION: 12.02, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123440/260-123440-0004.wav
# r:i can't pray to have the things i want he said slowly and i won't pray not to have them not if i'm damned for it
# p:i can't pray to have the bings i want he said slowly and i won't pray not to have them not if i'm bdamed for it
# 12: WER: 0.0224215246637, DURATION: 8.92, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/134500/237-134500-0041.wav
# r:missus neverbend you must indeed be proud of your son
# p:missus neverben you mustn't de be proud of your son
# 13: WER: 0.0961538461538, DURATION: 3.525, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0012.wav
# r:underscore these words for they are full of comfort for sore consciences
# p:underscore these words for there are full of comfort for sore consciences
# 14: WER: 0.0206896551724, DURATION: 5.415, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0063.wav
# r:what shall we do with the mingoes at the door they count six and this singer is as good as nothing
# p:what shall we do with the mingoes at the door they count six and the singer s is good as nothing
# 15: WER: 0.0309278350515, DURATION: 5.335, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0021.wav
# r:ambrose met me at the bottom of the stairs and showed me the way to the supper room
# p:ambrosmet me at the bottom of the stairs and showed me the way to the supper room
# 16: WER: 0.0181818181818, DURATION: 3.91, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/36377/5142-36377-0003.wav
# r:i don't know and can't say how you fine gentlemen define wickedness only as an obscure female i speak according to my lights and he is generally thought the wickedest man in this county
# p:i don't know wen can't say how you find gentleman to find wickedness only as an abscure female i speak a cording to my lights and he as generally thought the wickedest man in this county
# 17: WER: 0.0619946091644, DURATION: 13.26, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32866/5683-32866-0009.wav
# r:pack as much into my trunk as you can my traveling kit my suits shirts and socks don't bother counting just squeeze it all in and hurry
# p:pack as much into my trunk as you can much tr avelling hit my suits sharts and socks don't byther counting just squeeze it all in and hurry
# 18: WER: 0.043795620438, DURATION: 9.3, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/294828/8463-294828-0017.wav
# r:every plant in the grass is set formally grows perfectly and may be realized completely
# p:every plant in the grass is set formarly grows perfectly ind may be realized completely
# 19: WER: 0.0229885057471, DURATION: 6.625, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0033.wav
# r:mistress fitzooth had been carried off by the sheriff's daughter and her maids as soon as they had entered the house so that robin alone had the care of montfichet
# p:mistress fitzooth had been carried off whyn the sterof staughter in her maids as soon as they had entered the house o that robin alone had the care of monfe shee
# 20: WER: 0.0864197530864, DURATION: 7.86, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0054.wav
# r:the world brands this a pernicious doctrine
# p:the world rans this a pernicious doctrine
# 21: WER: 0.0238095238095, DURATION: 3.02, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0042.wav
# r:but i do not think such an inference is warranted
# p:but i do not think such an efference is waranted
# 22: WER: 0.0515463917526, DURATION: 3.62, PATH: /mnt/ml-data/LibriSpeech/test-clean/8230/279154/8230-279154-0008.wav
# r:above were three students one on each story
# p:above wer three students one on each story
# 23: WER: 0.0232558139535, DURATION: 2.705, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141083/1580-141083-0019.wav
# r:the hon charles smith miss sarah's brother was walking swiftly uptown from mister easterly's wall street office and his face was pale
# p:the honorable charles smith missaras brother was walking swiftly uptown fror mister easterly's wall streat office and his face was pale
# 24: WER: 0.0522388059701, DURATION: 8.955, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1836/1995-1836-0000.wav
# r:it is necessary therefore that he should comply the king frowned
# p:it is necessary therefore that he should comply the king frown
# 25: WER: 0.015873015873, DURATION: 4.755, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75946/7127-75946-0007.wav
# r:he felt he was up against it and that perhaps another kind of a job would suit him better
# p:he felt he was up against it and that perhaps another kind of a job would suit him batter
# 26: WER: 0.0112359550562, DURATION: 5.61, PATH: /mnt/ml-data/LibriSpeech/test-clean/2300/131720/2300-131720-0038.wav
# r:we think that by some little work or merit we can dismiss sin
# p:we think that by some little work re merin we can thismiss and
# 27: WER: 0.121951219512, DURATION: 3.96, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0071.wav
# r:the incident was not violent nor even dramatic no posse was summoned no further effort made and reeder fearing personal violence soon fled in disguise
# p:the incident was not byolent nor even germatic no posse was summoned no further effort made and reader fearing personal violence soon fled in disguise
# 28: WER: 0.04, DURATION: 10.975, PATH: /mnt/ml-data/LibriSpeech/test-clean/7729/102255/7729-102255-0020.wav
# r:there is the slang of the affected lady as well as of the precieuses
# p:there is the sleg of the effected lady as well as of the presuses
# 29: WER: 0.0676691729323, DURATION: 6.2, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0022.wav
# r:you do me a great honour
# p:you do me a great on or
# 30: WER: 0.125, DURATION: 3.3, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0013.wav
# r:now be silent on your lives he began but the captured apprentice set up an instant shout
# p:now be silent on gont lives he began but the captured apprentice set up in instant shout
# 31: WER: 0.0454545454545, DURATION: 5.685, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0030.wav
# r:and then you came back not caring very much but it made no difference
# p:and then you came back ot carrying very much but it made no difference
# 32: WER: 0.0215827338129, DURATION: 5.4, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0042.wav
# r:hypocrite a horse dealer
# p:hear becrit a horse derer
# 33: WER: 0.265306122449, DURATION: 3.165, PATH: /mnt/ml-data/LibriSpeech/test-clean/121/121726/121-121726-0014.wav
# r:natty harmon tried the kitchen pump secretly several times during the evening for the water had to run up hill all the way from the well to the kitchen sink and he believed this to be a continual miracle that might give out at any moment
# p:natti harmon tried the kitchen pump sacretly several times sduring the evening for the water had derun up hill all the lay from the well to the kitchen sank and he believed this to be at continual amerable that might give out at any moment
# 34: WER: 0.0420168067227, DURATION: 14.36, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/41806/4992-41806-0000.wav
# r:and it ruins a man's disposition
# p:and it rulds of an's just position
# 35: WER: 0.242424242424, DURATION: 2.505, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68769/6829-68769-0038.wav
# r:throughout the entire evolution of conspicuous expenditure whether of goods or of services or human life runs the obvious implication that in order to effectually mend the consumer's good fame it must be an expenditure of superfluities
# p:throughout the entire evolution of conspicous expenditure whether of good sor of services or human life runs the obvious implication that in order to affectually mend the consumous good fame it must be an expenditure of superfluties
# 36: WER: 0.0278372591006, DURATION: 13.025, PATH: /mnt/ml-data/LibriSpeech/test-clean/3570/5696/3570-5696-0005.wav
# r:the ingenious hawkeye who recalled the hasty manner in which the other had abandoned his post at the bedside of the sick woman was not without his suspicions concerning the subject of so much solemn deliberation
# p:the engenuous hackeye who were called the hasty manner in which the other had abandoned his post at the bedside of the sick woman was not without his suspicions concerning the subject of so much solemn deliberation
# 37: WER: 0.0211764705882, DURATION: 12.26, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0004.wav
# r:direction
# p:direction
# 38: WER: 0.0, DURATION: 1.42, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0041.wav
# r:everything he has done has been aimed at the conservation of energy the contraction of space the intensification of culture
# p:a rething he is done has been amed that the concerbation of energy the contraction of space the intensification of culture
# 39: WER: 0.069387755102, DURATION: 9.125, PATH: /mnt/ml-data/LibriSpeech/test-clean/2300/131720/2300-131720-0008.wav
# r:hold him fast my men and as soon as i've had my coffee and oatmeal i'll take him to the room of the great knife and patch him
# p:hold him fasti my men and as soon as iave had my coffee and a mol o'll take him to the room of the great knivt and pach him
# 40: WER: 0.0645161290323, DURATION: 8.61, PATH: /mnt/ml-data/LibriSpeech/test-clean/8555/284447/8555-284447-0001.wav
# r:did you ever have such a lordly guest before i went on
# p:did yrew over have such a lordly guest before i went on
# 41: WER: 0.0727272727273, DURATION: 3.945, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0035.wav
# r:keep away if you wish when have i ever followed you
# p:keep away if you wish when ave i ever followed you
# 42: WER: 0.00990099009901, DURATION: 3.08, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0034.wav
# r:the strong position held by the edison system under the strenuous competition that was already springing up was enormously improved by the introduction of the three wire system and it gave an immediate impetus to incandescent lighting
# p:the strong position held by the edison system under the stranuous competition tit was already springing up was inormously improved by the introduction of a three wire system and he gave an immediate empitest to incandiscent lighting
# 43: WER: 0.0515021459227, DURATION: 14.82, PATH: /mnt/ml-data/LibriSpeech/test-clean/2300/131720/2300-131720-0019.wav
# r:at once the goat gave a leap escaped from the soldiers and with bowed head rushed upon the boolooroo
# p:at once the goat gave a leap ascape from the soldiers and with vowed head rushed upon the booloroo
# 44: WER: 0.030303030303, DURATION: 5.46, PATH: /mnt/ml-data/LibriSpeech/test-clean/8555/284447/8555-284447-0018.wav
# r:and so the story of mormonism runs on its finale has not yet been written the current press presents continuously new stages of its progress new developments of its plan
# p:and so the story of morminism runs on its fenalley has not yet been written the current press presents continuously new statges of its progress new developments of its plan
# 45: WER: 0.0205278592375, DURATION: 11.895, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13754/4077-13754-0016.wav
# r:there was no chance to alter his sleeping room to one nearer to gamewell's chamber
# p:there was no chance to alter his sleeping room to one yearer to gaimwells chamber
# 46: WER: 0.0429447852761, DURATION: 4.35, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70970/61-70970-0013.wav
# r:isn't he splendid cried jasper in intense pride swelling up father knew how to do it
# p:isn't esplendid cried jasper and intense pride swelling up father  knew how to do it
# 47: WER: 0.0414201183432, DURATION: 6.71, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/126133/237-126133-0011.wav
# r:o little cloud the virgin said i charge thee to tell me why thou complainest now when in one hour thou fade away then we shall seek thee but not find ah thel is like to thee
# p:oh little cloud the virtin said i charged thee to tell  me why thou complain as now when in one hour thou fataway then we shall seek thee but not fine ah fall as like to thee
# 48: WER: 0.0720461095101, DURATION: 14.465, PATH: /mnt/ml-data/LibriSpeech/test-clean/908/157963/908-157963-0015.wav
# r:no said the tree
# p:no said the tree
# 49: WER: 0.030303030303, DURATION: 2.675, PATH: /mnt/ml-data/LibriSpeech/test-clean/672/122797/672-122797-0062.wav
# r:she a tory and clergyman's daughter was always in a minority of one in our house of violent dissent and radicalism
# p:she adtorian clerediman's daughter was always in a minority of one in our house of violent dessent and rodicalism
# 50: WER: 0.0660792951542, DURATION: 7.34, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0005.wav
# r:and yesterday things went on just as usual
# p:and yesterday thanks went on just as usual
# 51: WER: 0.047619047619, DURATION: 3.105, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123440/260-123440-0005.wav
# r:of this second letter also she spoke and told me that it contained an invitation for her to go and see the poet if ever she visited the lakes
# p:of this econd letter also she spoke and told me that it cantained an invitation for her to go and see the poet if ever she visited the lakes
# 52: WER: 0.0106761565836, DURATION: 8.9450625, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0030.wav
# r:and often has my mother said while on her lap i laid my head she feared for time i was not made but for eternity
# p:and of in has my mother' said while on her lap i laid my head she feared for time i was not made but fr ee tornity
# 53: WER: 0.0442477876106, DURATION: 8.23, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0000.wav
# r:the wine did certainly bring back the color to the squire's cheeks
# p:the windid certainly bring back the colour to the squire's cheeks
# 54: WER: 0.0229007633588, DURATION: 3.565, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0056.wav
# r:the ladies in compliance with that softness of heart which is their characteristic are on one side and the men by whom the world has to be managed are on the other
# p:the ladies and compliance with that softness of heart which is their characteristic ar on one side and the men by whom the world has to be managed or on the other
# 55: WER: 0.0215384615385, DURATION: 11.835, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0008.wav
# r:he had no friend wise enough to tell him to step into the dorking convention then in session make a sketch of the men and women on the platform and take it to the editor of the daily grapevine and see what he could get a line for it
# p:ye had no friend wise enough to tell him to sept into the doorking convention than insession make a scetch of the men and women on the platform and take itto the editor of the daily grape vine and see what he hould get awine for it
# 56: WER: 0.036717062635, DURATION: 14.3, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29093/4970-29093-0010.wav
# r:this knowledge is memory in one sense though in another it is not
# p:this knowledge is memory and one sense though in another it is not
# 57: WER: 0.0229007633588, DURATION: 4.59, PATH: /mnt/ml-data/LibriSpeech/test-clean/8230/279154/8230-279154-0039.wav
# r:you know i have just been telling you how this school of materialism and clay involved itself at last in cloud and fire
# p:you know i have just been tie you how this school materialism ind clay involved itself at last in cloud and fire
# 58: WER: 0.047619047619, DURATION: 7.45, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0025.wav
# r:he must descend with his heart full of charity and severity at the same time as a brother and as a judge to those impenetrable casemates where crawl pell mell those who bleed and those who deal the blow those who weep and those who curse those who fast and those who devour those who endure evil and those who inflict it
# p:hu must descend with his heart full of cherity and severity at the same time as a brother and as a judge to those impenetrable case mats where crawl pele new those who beleed in those who deal the blow those who reep in those who curse thougse who fast an those who devour those who endure evil and those who inflicted
# 59: WER: 0.0470219435737, DURATION: 28.09, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0032.wav
# r:luis was out of danger in a fortnight in a month he rose from his bed and during all that time he was visited daily by his mother and grandmother and treated by the master and mistress of the house as if he was their own child
# p:lois was out of danger in a fortnight and a month he rose from his bed and drewing all that time he was visited daily by his mother and grandmother and treated by the master and mistress of the house as if he was their own child
# 60: WER: 0.0220264317181, DURATION: 14.5, PATH: /mnt/ml-data/LibriSpeech/test-clean/5639/40744/5639-40744-0026.wav
# r:a great saint saint francis xavier
# p:a great saint saint frances zavior
# 61: WER: 0.0882352941176, DURATION: 3.25, PATH: /mnt/ml-data/LibriSpeech/test-clean/1089/134686/1089-134686-0036.wav
# r:i wish i knew myself she cried fiercely
# p:i wish i knew myself she cried fiercely
# 62: WER: 0.0126582278481, DURATION: 2.475, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68771/6829-68771-0034.wav
# r:rodolfo and his companions with their faces muffled in their cloaks stared rudely and insolently at the mother the daughter and the servant maid
# p:wrudolphil and his companions wheth her faces muffled in their cloaks stared rodily and insolently at the mother the daughter and the servant made
# 63: WER: 0.0758620689655, DURATION: 8.91, PATH: /mnt/ml-data/LibriSpeech/test-clean/5639/40744/5639-40744-0002.wav
# batch mean WER: 0.0494925985871
# r:they knew no north no south no east no west they stood positively by the constitution and would have nothing to do in the bloody strife between brothers unless indeed they were summoned by the authority to which they had already once loyally responded to furnish men and arms for their country's need
# p:they knew no north no south no east now esk they saod positively by the constitution and whan have nothing to do in the bloody strife between brothers inless in deed theye were summoned by the authority too hich they had already once loedly responded to furnish men in arms for they countries need
# 0: WER: 0.0653266331658, DURATION: 17.84, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13754/4077-13754-0005.wav
# r:as the ambassador of a government is honored for his office and not for his private person so the minister of christ should exalt his office in order to gain authority among men
# p:as the ambassador of a government is honored for his office and not for his private person so the minister of chris should exalt his office in order to gain a uthority among men
# 1: WER: 0.00564971751412, DURATION: 10.19, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0007.wav
# r:we do not know how plato would have arranged his own dialogues or whether the thought of arranging any of them besides the two trilogies which he has expressly connected was ever present to his mind
# p:we do not know how plato would have arranged his own dialetes or wether the thought of a ranging any of them besides the to trillagis which he has expressly connected was ever present to his mind
# 2: WER: 0.0330788804071, DURATION: 15.455, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/960/2961-960-0008.wav
# r:thy ways greatly try me ruth and all thy relations
# p:thy ways greatly tryd me ruth and all thy relations
# 3: WER: 0.00990099009901, DURATION: 4.65, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29095/4970-29095-0005.wav
# r:he cried in high dudgeon just as if he owned the whole of the peppers and could dispose of them all to suit his fancy
# p:he cried and hide dugan just as if he owned the whole of the peppers and could dispose of them all do suith his mancy
# 4: WER: 0.0683760683761, DURATION: 6.675, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/126133/237-126133-0023.wav
# r:it might have seemed that a trout of this size was a fairly substantial meal
# p:in mint have seemed that a trout of this ize was a fairly substantial meal
# 5: WER: 0.04, DURATION: 4.295, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/88083/7176-88083-0006.wav
# r:poyser is not at home is he
# p:poiser is not at home asse
# 6: WER: 0.132075471698, DURATION: 2.21, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0047.wav
# r:the world is all there just as it used to be but i can't get at it any more
# p:the world is all there just as it used to be but i can't get ad it any more
# 7: WER: 0.0133333333333, DURATION: 4.93, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0019.wav
# r:it is a duty said i
# p:it is a duty said i
# 8: WER: 0.0, DURATION: 2.14, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0032.wav
# r:this attitude is universal and particularly developed in those who consider themselves better than others
# p:the savitude is universal inparticularly developed in those who consider themselves etter than others
# 9: WER: 0.0679611650485, DURATION: 5.7, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0074.wav
# r:he wanted to begin at the top of the ladder
# p:he wanted to begin at the top of the ladter
# 10: WER: 0.0344827586207, DURATION: 3.58, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29093/4970-29093-0008.wav
# r:i painted the eyes red for anger
# p:i painted the eyes red for anger
# 11: WER: 0.0153846153846, DURATION: 2.11, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0008.wav
# r:on saturday mornings when the sodality met in the chapel to recite the little office his place was a cushioned kneeling desk at the right of the altar from which he led his wing of boys through the responses
# p:on saturday mornings when the sodelity meant in the chapel to recite the little office his place was accushioned kneeling desk at the right of the altar from which he led his wing of boys through the responses
# 12: WER: 0.0144230769231, DURATION: 12.445, PATH: /mnt/ml-data/LibriSpeech/test-clean/1089/134686/1089-134686-0011.wav
# r:the most famous of them all was the overthrow of the island of atlantis
# p:the most faenors of them all was the overthrol of the island of a twentests
# 13: WER: 0.109589041096, DURATION: 5.29, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/961/2961-961-0018.wav
# r:the wizard of oz who used to be a humbug and knew no magic at all has been taking lessons of glinda and i'm told he is getting to be a pretty good wizard but he is merely the assistant of the great sorceress
# p:the wisard of eyes pol used to be a humbug a new no majic at all has been takeng lessons of glenda and nom told he is getting to be a pretty good wizard but he is merely the assistant of the great sourceres
# 14: WER: 0.0702179176755, DURATION: 11.775, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1181/1284-1181-0017.wav
# r:in all early gothic art indeed you will find failure of this kind especially distortion and rigidity which are in many respects painfully to be compared with the splendid repose of classic art
# p:in all eardly gothicardendeed you will find phailure of this kind especially distortion in regidity which are an many respects painfully to be compared with the splendid repose of classic art
# 15: WER: 0.0443864229765, DURATION: 11.5499375, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0018.wav
# r:it won't be much but i'm grateful to find a friend
# p:it won't be much but im grateful to find a friend
# 16: WER: 0.010101010101, DURATION: 2.755, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68769/6829-68769-0035.wav
# r:you can begin by carrying a rod and putting down the figures
# p:you can begin ry carrying ae wrod and puing down the figures
# 17: WER: 0.0578512396694, DURATION: 3.325, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29093/4970-29093-0015.wav
# r:from the respect paid her on all sides she seemed like a queen and from the adoration with which she was treated by two or three she appeared an object of worship the queen mother gave the french the most affectionate reception france was her native country and she had suffered too much unhappiness in england for england to have made her forget france
# p:from the respect paid her on all sides she seemed like a queen and from the ado ation with which she was treated by two or three she appeared and object of worship but queen mother gave the french the most effectionate reception france was her native country and she had suffered too much inhappiness in england for england to have made her forgit frience
# 18: WER: 0.0267983074753, DURATION: 23.315, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/75918/6930-75918-0003.wav
# r:but was that all her reward one of the ladies asked
# p:but was that all her reward won a lady's eusk
# 19: WER: 0.208333333333, DURATION: 4.15, PATH: /mnt/ml-data/LibriSpeech/test-clean/121/127105/121-127105-0036.wav
# r:there jap you've caught it laughed percy while the others screamed at the sight of jasper's face
# p:there dap you've caught it laped perse while the other screamed at beside of jaspers pace
# 20: WER: 0.129032258065, DURATION: 6.21, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/126133/237-126133-0017.wav
# r:when it is a question of probing a wound a gulf a society since when has it been considered wrong to go too far to go to the bottom
# p:when it is a question of proping a wound a gol ase wofsiety since wen has ard been considered rong to go to far to go to the bottom
# 21: WER: 0.0763358778626, DURATION: 11.305, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0009.wav
# r:i think the next glass cat the magician makes will have neither brains nor heart for then it will not object to catching mice and may prove of some use to us
# p:i think the next glass cab the magician makes will have neither brains nor heart for then it will not object to catching myce and they prove of sone used to us
# 22: WER: 0.0379746835443, DURATION: 9.84, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1180/1284-1180-0021.wav
# r:hello stephanos here comes the dedalus
# p:hallo stuffanase here comes the dediles
# 23: WER: 0.194805194805, DURATION: 3.99, PATH: /mnt/ml-data/LibriSpeech/test-clean/1089/134691/1089-134691-0020.wav
# r:an article may be useful and wasteful both and its utility to the consumer may be made up of use and waste in the most varying proportions
# p:and artica maybe useful and waistful both and its etility to the consero may be made up of use and waste in the most vering proportions
# 24: WER: 0.0549450549451, DURATION: 7.57, PATH: /mnt/ml-data/LibriSpeech/test-clean/3570/5696/3570-5696-0010.wav
# r:on huge silver platters were pyramids of tarts and cakes and red wine sparkled in glittering decanters
# p:on huge silver platters wore pyramids of tarts and cakes and red wine sparkled in glittering to canters
# 25: WER: 0.0341463414634, DURATION: 8.015, PATH: /mnt/ml-data/LibriSpeech/test-clean/7021/85628/7021-85628-0010.wav
# r:a sound of voices a flash of light
# p:a sound of voices are flash of light
# 26: WER: 0.0422535211268, DURATION: 3.835, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/81414/6930-81414-0010.wav
# r:ben zoof's most ambitious desire was to induce the captain to go with him and end his days in his much loved home and so incessantly were servadac's ears besieged with descriptions of the unparalleled beauties and advantages of this eighteenth arrondissement of paris that he could scarcely hear the name of montmartre without a conscious thrill of aversion
# p:benzops most embitious desire was to induce the captain to go with him and end his days in his much loved home and so incessantly were servid ax ears besieged with the scriptions of the unperallel beautis and advantages of this eighteenth are un dissimman of paris that he could scarcely hear the name of montmartra without a conscious thrill of aversion
# 27: WER: 0.0576652601969, DURATION: 26.14, PATH: /mnt/ml-data/LibriSpeech/test-clean/5105/28233/5105-28233-0007.wav
# r:and one more this morning
# p:and one more thes morning
# 28: WER: 0.0588235294118, DURATION: 2.06, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141084/1580-141084-0022.wav
# r:but i wrestled with this fellow and do know that he played unfairly in the second bout
# p:but i restled with this fellow and do know that he played on fairly in the second bot
# 29: WER: 0.0292397660819, DURATION: 5.025, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0023.wav
# r:eliza parsons shook her head
# p:alizaparson shook her head
# 30: WER: 0.0740740740741, DURATION: 2.125, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68771/6829-68771-0026.wav
# r:you'll never dig it out of the astor library
# p:you'll never dige it out of the aster whibary
# 31: WER: 0.0786516853933, DURATION: 3.03, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29093/4970-29093-0000.wav
# r:for a few miles she followed the line hitherto presumably occupied by the coast of algeria but no land appeared to the south
# p:for a few miles she followed the line hitherto presumably occupied by the coast of algeria but no land appeared to the south
# 32: WER: 0.0, DURATION: 8.415, PATH: /mnt/ml-data/LibriSpeech/test-clean/5105/28241/5105-28241-0005.wav
# r:old dances are simplified of their yearning bleached by time
# p:old dances are simpleified at their yearning bleached by time
# 33: WER: 0.0413223140496, DURATION: 5.77, PATH: /mnt/ml-data/LibriSpeech/test-clean/8555/292519/8555-292519-0010.wav
# r:she looked at his heavy shoulders and big determined head thrust forward like a catapult in leash
# p:she looked at his heavy shoulders and bigg determined head frst forward like caterpuldon lych
# 34: WER: 0.105263157895, DURATION: 6.025, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0012.wav
# r:yes something everything said rachel hurriedly looking frowningly at a flower which she was twirling in her fingers
# p:yes something everything said rechel hearidly looking frowningly out a flower whuch she was twirling in her fingers
# 35: WER: 0.0521739130435, DURATION: 8.405, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32879/5683-32879-0014.wav
# r:we sunk his ship and men but him we brought to you
# p:we sunk as ship and men that him we brought to you
# 36: WER: 0.0891089108911, DURATION: 3.075, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0057.wav
# r:but they dragged him out of the room and up the stairs into the loft and here in a dark corner where no daylight could enter they left him
# p:but they dragged him out of the room and up the stairs into the loft and here it had dark corner where no daylight could enter they left him
# 37: WER: 0.0179211469534, DURATION: 15.31, PATH: /mnt/ml-data/LibriSpeech/test-clean/672/122797/672-122797-0042.wav
# r:forgive me i hardly know what i am saying a thousand times forgive me madame was right quite right this brutal exile has completely turned my brain
# p:forgive me i hardly know what i am saying a thousand times forgive me madame was aright quite right this brutal exile has completely turned my brain
# 38: WER: 0.00338983050847, DURATION: 10.115, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75947/7127-75947-0014.wav
# r:she has a son theft and a daughter hunger
# p:she has a son theft an adaughter hunger
# 39: WER: 0.025, DURATION: 4.895, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0003.wav
# r:he moved uneasily and his chair creaked
# p:he moved uneasily ind his chair creaked
# 40: WER: 0.025641025641, DURATION: 2.995, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0027.wav
# r:here they said is a rascal who has been harrying our coasts
# p:here they said is a rouscal whose been herry ark coasts
# 41: WER: 0.175438596491, DURATION: 3.07, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0056.wav
# r:but at this point in the rapids it was impossible for him to stay down
# p:but it this point in the rapids it was impossible for him to stay down
# 42: WER: 0.0142857142857, DURATION: 3.66, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/88083/7176-88083-0017.wav
# r:do not therefore think that the gothic school is an easy one
# p:do not therefore think that the goth exchools an easy one
# 43: WER: 0.0769230769231, DURATION: 4.39, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0014.wav
# r:ham to be or not to be
# p:him to be or not to be
# 44: WER: 0.0454545454545, DURATION: 2.16, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/92135/7176-92135-0010.wav
# r:those huge creatures attacked each other with the greatest animosity
# p:those huge creatures attack each other with a greatest enimosity
# 45: WER: 0.0606060606061, DURATION: 4.545, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123286/260-123286-0029.wav
# r:the revelation of his love lighted and brightened slowly till it flamed like a sunrise over him and left him in burning wonder
# p:who revelation of his love lighted and rightened slowly do at flame like a sunrise over him and left him in runing wonder
# 46: WER: 0.0688259109312, DURATION: 7.36, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1837/1995-1837-0003.wav
# r:lend me your ear for ten minutes and you shall learn just what stagecraft is
# p:linme or ear for ten minutes a nu shall learn just what stage craft is
# 47: WER: 0.0821917808219, DURATION: 4.43, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/92135/7176-92135-0008.wav
# r:there cannot be a doubt he received you kindly for in fact you returned without his permission
# p:there cannot be a doubt he received you kindly for in fact you returned without his peromission
# 48: WER: 0.00529100529101, DURATION: 6.26, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75947/7127-75947-0015.wav
# r:my pursuits are peaceful and my temper i humbly trust is greatly given to mercy and love returned david a little nettled at so direct an attack on his manhood but there are none who can say that i have ever forgotten my faith in the lord even in the greatest straits
# p:my pursuits are peaceful on my temper i hambly trust as greatly given to mercy an love returned david a little nettle that so directs and attack on his manhood but there are none who can say that i have ever forgotten my faith in the lord even in the greatest straets
# 49: WER: 0.031894934334, DURATION: 15.995, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0028.wav
# r:well as i say it's an awful queer world they clap all the burglars into jail and the murderers and the wife beaters i've allers thought a gentle reproof would be enough punishment for a wife beater cause he probably has a lot o provocation that nobody knows and the firebugs can't think o the right name something like cendenaries an the breakers o the peace an what not an yet the law has nothin to say to a man like hen lord
# p:well as i say it's an awful queer world they clap all the burglers and da on the murderers in the white beaters i all ares thoht a gentle reprov ol be enough punishment for a wife beater cause he probably has a lot a provocation that nobody knows and the firebugs can't think of the right name somethe lig sendiaris and the brakers of the pece and wat not and yet the law has nothin to say to me like handlord
# 50: WER: 0.0802395209581, DURATION: 28.41, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/41797/4992-41797-0001.wav
# r:but the more forgetfulness had then prevailed the more powerful was the force of remembrance when she awoke
# p:but the more forgetfulness had then prevailed the more powerful was the force ot remembrance when she awoke
# 51: WER: 0.00934579439252, DURATION: 6.645, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/23283/4992-23283-0000.wav
# r:but anders cared nothing about that
# p:but anter's cared nothing about that
# 52: WER: 0.0422535211268, DURATION: 3.02, PATH: /mnt/ml-data/LibriSpeech/test-clean/7021/85628/7021-85628-0000.wav
# r:my bed was unexceptionably comfortable but in my then mood i could have wished it a great deal more modern
# p:my bad was unexceptional ly comfortable but in my than mood i could have wished it a great deal more modern
# 53: WER: 0.0328638497653, DURATION: 7.9, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32866/5683-32866-0021.wav
# r:the stop at queenstown the tedious passage up the mersey were things that he noted dimly through his growing impatience
# p:the stop at queent's town that tedious passage up the mercy were things that he noted dimly through his growing impatience
# 54: WER: 0.0373443983402, DURATION: 6.34, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0000.wav
# r:the world was water veiled in mists
# p:who world was water vailed o mists
# 55: WER: 0.130434782609, DURATION: 2.955, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1837/1995-1837-0006.wav
# r:make acquaintance with mister jago sit together
# p:make a quaintance with misyogo sick together
# 56: WER: 0.152173913043, DURATION: 2.715, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/36377/5142-36377-0012.wav
# r:the electric light can scarcely penetrate through the dense curtain which has dropped over the theatre on which the battle of the elements is about to be waged
# p:the electric light con scarcely penetrateing the danse curtan which is trobped over the theatre on which the battle of the elements is about to be waged
# 57: WER: 0.0675241157556, DURATION: 8.905, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123288/260-123288-0003.wav
# r:at dinner lake was easy and amusing
# p:at dinner leke was easy and amusing
# 58: WER: 0.0285714285714, DURATION: 3.35, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32865/5683-32865-0006.wav
# r:now then let's enter the city an enjoy the grand feast that's being cooked i'm nearly starved myself for this conquerin kingdoms is hard work
# p:now then lets enter the city and enjoy tha great feast its being cot i nearly starmyself for this congren kingdoms as hard work
# 59: WER: 0.126865671642, DURATION: 9.31, PATH: /mnt/ml-data/LibriSpeech/test-clean/8555/284449/8555-284449-0007.wav
# r:women can hide their pain better than we men and bear it better too except when shame drops fire into the dreadful chalice
# p:women can hide their pain better than we men and bear it tat ar two except when shame drops fire into the druadful chalice
# 60: WER: 0.0491803278689, DURATION: 9.345, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32879/5683-32879-0003.wav
# r:nothing will be more precious to you i think in the practical study of art than the conviction which will force itself on you more and more every hour of the way all things are bound together little and great in spirit and in matter
# p:nothing will be more precious to you i thank in the practical study of art then the conviction which will force itself o new morand more every hour of the way all things are bound together little and great in spirit and imatter
# 61: WER: 0.0326797385621, DURATION: 15.24, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0024.wav
# r:at the foot of the mountain that separated the country of the munchkins from the country of the gillikins the path divided
# p:at the foot of the mountain that separated the country of the munchkins from the country of the gillikans the path divided
# 62: WER: 0.00819672131148, DURATION: 6.865, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1180/1284-1180-0006.wav
# r:he had the faith in him that moves mountains
# p:he had the faith in him that moves mountains
# 63: WER: 0.0, DURATION: 3.445, PATH: /mnt/ml-data/LibriSpeech/test-clean/1089/134686/1089-134686-0035.wav
# batch mean WER: 0.0564628584052
# r:it is hardly necessary to say more of them here
# p:it is hardly necessary to say more of them here
# 0: WER: 0.0, DURATION: 3.545, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/287645/8463-287645-0001.wav
# r:there were a few rose bushes however and a number of apple trees probably the descendants of those planted by the reverend mister blackstone the first settler of the peninsula that half mythological personage who rides through our early annals seated on the back of a bull
# p:there were a few rose bushes however and a number of aple trees probably the descendants of those planted by the reverent o mister blackstone the first settleer of the pinnansula that half mithalogical personage who rides through our early annals seated on the back of a ball
# 1: WER: 0.0310786106033, DURATION: 16.27, PATH: /mnt/ml-data/LibriSpeech/test-clean/1221/135767/1221-135767-0023.wav
# r:edison held that the electricity sold must be measured just like gas or water and he proceeded to develop a meter
# p:ever sin hel that the electricity sould must be measured just like gas oer water an he perceeded to develop ammeter
# 2: WER: 0.0789473684211, DURATION: 8.62, PATH: /mnt/ml-data/LibriSpeech/test-clean/2300/131720/2300-131720-0027.wav
# r:relocated footnote governor robinson being on his way east the steamboat on which he was traveling stopped at lexington missouri
# p:relocated footnout gathernor robinson being on his way east the steam boat on which he was traveling stopped at lecxington asouri
# 3: WER: 0.0583657587549, DURATION: 9.225, PATH: /mnt/ml-data/LibriSpeech/test-clean/7729/102255/7729-102255-0042.wav
# r:tabby had tended them in their childhood they and none other should tend her in her infirmity and age
# p:tabby had tended them in their tildhood they and none other should tend her in her infirmity ind age
# 4: WER: 0.0248756218905, DURATION: 6.405, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0050.wav
# r:it will not be safe for you to stay here now
# p:it will not be safe for you to stay here now
# 5: WER: 0.0, DURATION: 2.77, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0044.wav
# r:he sat down weak bewildered and one thought was uppermost zora
# p:besat down weak bewildered and one thought was uppermost so
# 6: WER: 0.0578512396694, DURATION: 5.38, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1837/1995-1837-0019.wav
# r:meter roughly one yard three inches
# p:madeer reughly one yard three anches
# 7: WER: 0.12676056338, DURATION: 2.935, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/294825/8463-294825-0018.wav
# r:this truth which i have learned from her lips is confirmed by his face in which we have both beheld that of our son
# p:this truth which i have learned from her alips is confirmed by his face in which we have both beheld that of our son
# 8: WER: 0.004329004329, DURATION: 7.305, PATH: /mnt/ml-data/LibriSpeech/test-clean/5639/40744/5639-40744-0029.wav
# r:but do not suppose that i disparage the gift which you possess nor that i would discourage you from exercising it i only exhort you so to think of it and so to use it as to render it conducive to your own permanent good
# p:but do not suppose that i despairage the gift which you possess nor that i would discoure you from exercising it i only exhort you so to think of it and so to use it as to render it candoceifety your own permanent good
# 9: WER: 0.0343249427918, DURATION: 14.425, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0015.wav
# r:in this connection it should be mentioned that the association of edison illuminating companies in the same year adopted resolutions unanimously to the effect that the edison meter was accurate and that its use was not expensive for stations above one thousand lights and that the best financial results were invariably secured in a station selling current by meter
# p:in this connection it should be mentioned that the association of atison alluminating companies in the same year adopted resolutions unanimously to the effect that the editon meter was aoccurate and that its use was not expensive for stations above one thousand lights and that the best fanantial results were invariably secured ind a station seling current by metr
# 10: WER: 0.0219178082192, DURATION: 25.49, PATH: /mnt/ml-data/LibriSpeech/test-clean/2300/131720/2300-131720-0035.wav
# ...
# 12: WER: 0.0277777777778, DURATION: 4.02, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68769/6829-68769-0033.wav
# r:and god the father who raised him from the dead
# p:an got the father who raised him from the dead
# 13: WER: 0.0322580645161, DURATION: 2.91, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0021.wav
# r:her regard shifted to the green stalks and leaves again and she started to move away
# p:her regard shifted to the green stolks and leaves again and she started to move away
# 14: WER: 0.0119047619048, DURATION: 5.01, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1826/1995-1826-0018.wav
# r:margolotte had first made the girl's form from the patchwork quilt and then she had dressed it with a patchwork skirt and an apron with pockets in it using the same gay material throughout
# p:largalot had first made the girls form from the patchwork quilled and then she had dressed it with the patch work skirt and in apron with pockets in it husing the same game material through out
# 15: WER: 0.0603674540682, DURATION: 11.43, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1181/1284-1181-0001.wav
# r:in those very terms i even added more
# p:in those very terms i even had admore
# 16: WER: 0.0810810810811, DURATION: 2.94, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/75918/6930-75918-0013.wav
# r:yes then something better something still grander will surely follow or wherefore should they thus ornament me
# p:yes ind something better something still praner will surely follow or wherefore should they thus ornament me
# 17: WER: 0.045871559633, DURATION: 9.215, PATH: /mnt/ml-data/LibriSpeech/test-clean/672/122797/672-122797-0016.wav
# r:miss woodley was too little versed in the subject to know this would have been not to love at all at least not to the extent of breaking through engagements and all the various obstacles that still militated against their union
# p:miss woodley was too little versdon the subject to now this would have been not to love it all at least not to the extent of breaking through engagements and all the various obstacles that still metigated against their union
# 18: WER: 0.0288248337029, DURATION: 14.315, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/23283/4992-23283-0017.wav
# r:they regained their apartment apparently without disturbing the household of gamewell
# p:they regain their apart met apparently without disturbing the household of gainwell
# 19: WER: 0.047619047619, DURATION: 4.165, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70970/61-70970-0040.wav
# r:oh yes said jack and i'm nowhere
# p:oh yes said jack and i'm nowhere
# 20: WER: 0.0, DURATION: 3.155, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0020.wav
# r:i tell him to give me some coffee if it is good
# p:i torn to give me some coffee if it is good
# 21: WER: 0.120879120879, DURATION: 3.305, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0019.wav
# r:oh you are the dearest and best mister king i ever saw but how did you make mammy let her come
# p:oh you are but dearest an best mister king i ever saw but how did you make mammy let her come
# 22: WER: 0.0374331550802, DURATION: 6.24, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/126133/237-126133-0010.wav
# r:bracton's a very good fellow i can assure you
# p:bragtons a very good fellow i can assure you
# 23: WER: 0.0337078651685, DURATION: 3.3, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32866/5683-32866-0008.wav
# r:the king had completed his toilette by nine o'clock he appeared in an open carriage decorated with branches of trees and flowers
# p:the kang had completed his toilet by nine o'clock he appeared and an open carriage decorated with branches of trees and flouers
# 24: WER: 0.0352941176471, DURATION: 8.58, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75946/7127-75946-0013.wav
# r:words was it their colours
# p:words was it their colours
# 25: WER: 0.0, DURATION: 3.395, PATH: /mnt/ml-data/LibriSpeech/test-clean/1089/134691/1089-134691-0015.wav
# r:just at the moment when the tears of the pitying beholders flowed fastest and their ejaculations were most expressive of despair leocadia gave signs of recovery and brought back gladness to the hearts of all
# p:jost at the moment when the tears of the pitting beholders flowed fastest and there ejaculations were most expressive of despair they occadia gove signs of recovery and brought back gladness for the hearts of al
# 26: WER: 0.0478468899522, DURATION: 13.8, PATH: /mnt/ml-data/LibriSpeech/test-clean/5639/40744/5639-40744-0038.wav
# r:but they have nothing to do with the interpretation of plato and in spirit they are opposed to him
# p:but they have nothing to do with the inth of wetation of platal and in spirit the are appose to him
# 27: WER: 0.0862944162437, DURATION: 7.64, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/960/2961-960-0007.wav
# r:the delawares are children of the tortoise and they outstrip the deer
# p:the delawares are children of the tortis an the outstripe the deer
# 28: WER: 0.037037037037, DURATION: 3.855, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0022.wav
# r:silas slunk away without a word of protest ambrose stood his ground evidently bent on making his peace with naomi before he left her seeing that i was in the way i walked aside toward a glass door at the lower end of the room
# p:silac lunka way without a word of protest ambro stoodhas ground evidently beent on making his piecewen noow mebfore he left er seeing that i was in the way i walked aside toward a glass doors the lower and of the room b
# 29: WER: 0.0900900900901, DURATION: 11.885, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/36377/5142-36377-0025.wav
# r:now delia contrived to obtain a great influence and ascendency over the minds of the children by means of these dolls
# p:now dula contrived to obtain a great influence and assendency over the mind of the children by means of these dolls
# 30: WER: 0.0258620689655, DURATION: 9.225, PATH: /mnt/ml-data/LibriSpeech/test-clean/7021/79740/7021-79740-0002.wav
# r:then he turned to me again frowning
# p:then he turned to me again frowning
# 31: WER: 0.0140845070423, DURATION: 2.215, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0066.wav
# r:i refer to the thermometer it indicates the figure is obliterated
# p:i referred athe themometer it ina cates the figure is abliterated
# 32: WER: 0.107692307692, DURATION: 4.865, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123288/260-123288-0016.wav
# r:never that sir he had said
# p:never that's ir he had said
# 33: WER: 0.0566037735849, DURATION: 2.335, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70970/61-70970-0006.wav
# r:right willingly for between us we have won the battle answered robin
# p:right willingly for between us we have won the battle answered brobin
# 34: WER: 0.00729927007299, DURATION: 3.95, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0040.wav
# r:nothing new weather unchanged the wind freshens
# p:nothing new whether unchanged the wind freshes
# 35: WER: 0.0537634408602, DURATION: 4.255, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123286/260-123286-0011.wav
# r:indeed there were only one or two strangers who could be admitted among the sisters without producing the same result
# p:indeed there were only one or two strangers who could be admitted among the sisteris wit producing the same result
# 36: WER: 0.021645021645, DURATION: 6.905, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0040.wav
# r:he is a welcome figure at the garden parties of the elect who are always ready to encourage him by accepting free seats for his play actor managers nod to him editors allow him to contribute without charge to a symposium on the price of golf balls
# p:he is a welcome pigure at the garden parties of the elect who were always vready to encourage him by eccepting free seats for his play acter managers nod to him and ers allow hem to contribute without charge to a some posium on the price of gulfballs
# 37: WER: 0.0583501006036, DURATION: 14.44, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/92135/7176-92135-0000.wav
# r:their sufferings have never yet been fitly chronicled by human scribe
# p:ther sufferings have never yet been fittly chronical by human scribe
# 38: WER: 0.0510948905109, DURATION: 4.315, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13751/4077-13751-0013.wav
# r:never did he object to buckling up his suitcase for any country whatever china or the congo no matter how far off it was
# p:never did he haveject to buckleing up his sutcase for any country whatever china are the congo no latter how far off it was
# 39: WER: 0.0573770491803, DURATION: 8.34, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/294828/8463-294828-0010.wav
# r:the count had thrown himself back on his seat leaning his shoulders against the partition of the tent and remained thus his face buried in his hands with heaving chest and restless limbs
# p:they count had the ron himself back on his seat leaning his shoulders against the partition of the tent and remained tus his face buried in his hands with heaving chest and restless limbs
# 40: WER: 0.0160427807487, DURATION: 13.16, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/75918/6930-75918-0005.wav
# r:he knows them both
# p:he knows them both
# 41: WER: 0.0, DURATION: 1.915, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0030.wav
# r:does thee think thee could stand it six months
# p:tis the think thee could stand it six months
# 42: WER: 0.0666666666667, DURATION: 3.355, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29095/4970-29095-0011.wav
# r:now the object of this soliloquy is plain
# p:now the object of this solleque is plain
# 43: WER: 0.0617283950617, DURATION: 2.885, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/92135/7176-92135-0011.wav
# r:i had a name i believe in my young days but i have forgotten it since i have been in service
# p:i had a name i believe in my young dan is but i have forgotten it sine i have been incervice
# 44: WER: 0.0486486486486, DURATION: 7.37, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0011.wav
# r:in fact he had just finished it the last of the trout's tail had just vanished with a spasm down his strained gullet when the baffled hawk caught sight of him and swooped
# p:in fact he had just minished it the last of the trouts taile had just bhen ished with a spasm down his strained gallet when the baffled hawk caught sight of him and swooped
# 45: WER: 0.0350877192982, DURATION: 10.06, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/88083/7176-88083-0011.wav
# r:on friday confession will be heard all the afternoon after beads
# p:on friday confession will be heard all the afternoon after beads
# 46: WER: 0.0, DURATION: 4.67, PATH: /mnt/ml-data/LibriSpeech/test-clean/1089/134686/1089-134686-0029.wav
# r:frank read english slowly and the more he read about this divorce case the angrier he grew
# p:frank red english stolly and a more he read about this to boarscase the angrier he grew
# 47: WER: 0.141242937853, DURATION: 6.13, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/134500/237-134500-0000.wav
# r:munny i tould ike to do into de barn to tommy to see de whittawd
# p:mony i dilighto do into the ban to tommy to see the win ard
# 48: WER: 0.235772357724, DURATION: 5.63, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0027.wav
# r:now to bed boy
# p:now to bed boy
# 49: WER: 0.0, DURATION: 2.15, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70970/61-70970-0008.wav
# r:but the proprietor appeared already to have relinquished as hopeless the effort to perpetuate on this side of the atlantic in a hard soil and amid the close struggle for subsistence the native english taste for ornamental gardening
# p:but the proprietor appeared already to have relinquished as hopeless the afort to prepetuate on this side of the atlantic an a hard soil and amid the close struggle for subsistence the native english taste for ornamental gardening
# 50: WER: 0.0195227765727, DURATION: 14.395, PATH: /mnt/ml-data/LibriSpeech/test-clean/1221/135767/1221-135767-0022.wav
# r:it was not very much past eleven that morning when the pony carriage from brandon drew up before the little garden wicket of redman's farm
# p:it was not very much passd aleven that morning when the pony carriage from brandon drew up before the little garden wicket of redman's farm
# 51: WER: 0.0180505415162, DURATION: 8.92, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32879/5683-32879-0000.wav
# r:we are losing time and the fact is i have not come all this way to take a little sail upon a pond on a raft
# p:we are lising time and the fact is i have not come all this way to take a little sail upon a paind on a wratt
# 52: WER: 0.037037037037, DURATION: 7.405, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123286/260-123286-0006.wav
# r:what then a human hand large and shapely appeared distinctly on the surface of the pond
# p:while then a human hand alarge and shaely appeared to stinctly on the surface of the poent
# 53: WER: 0.0898876404494, DURATION: 6.8, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/81414/6930-81414-0006.wav
# r:some of the touches indeed when the tint has been mixed with much water have been laid in little drops or ponds so that the pigment might crystallize hard at the edge
# p:some of the touches indeed when the tinters been mixed with much water have been laid and little drops or ponds so that the pigment might cristalize hard at the edge
# 54: WER: 0.0332326283988, DURATION: 10.65, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0004.wav
# r:dear me what a chatterbox you're getting to be unc remarked the magician who was pleased with the compliment
# p:dea me one o chater box or getting to be unc remarked them agician who was pleased with the compliment
# 55: WER: 0.0952380952381, DURATION: 6.73, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1181/1284-1181-0020.wav
# r:to do so is to lose god altogether because god becomes intolerable when we seek to measure and to comprehend his infinite majesty
# p:to do so as to lose god altogether because god becomes intolerable when we seek to measuren to comprehend this imfhinite majesty
# 56: WER: 0.0350194552529, DURATION: 7.865, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0047.wav
# r:i've seen lots of that kind in my day
# p:i sae lots o that kind on my day
# 57: WER: 0.130434782609, DURATION: 2.53, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68769/6829-68769-0037.wav
# r:his tones rang pleasantly on warrenton's ears and forthwith a good fellowship was heralded between them
# p:his tones ran pleasantly unworrinton's ears and forthwith the good fellow sip was herolded between them
# 58: WER: 0.0873786407767, DURATION: 5.98, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70970/61-70970-0037.wav
# r:so i set guards over every one in that house
# p:to i said gards over everyone in that house
# 59: WER: 0.113636363636, DURATION: 2.83, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0041.wav
# r:will you leave me alone in my own room or must i go away to escape you
# p:whul you leave be alone in my own room or must e go way to a scape you
# 60: WER: 0.0857142857143, DURATION: 4.39, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68771/6829-68771-0035.wav
# r:at another time harald asked
# p:at another time harold asked
# 61: WER: 0.0357142857143, DURATION: 2.005, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0000.wav
# r:the story's written
# p:the stories written
# 62: WER: 0.128205128205, DURATION: 2.11, PATH: /mnt/ml-data/LibriSpeech/test-clean/121/127105/121-127105-0004.wav
# r:so for the hundredth time she was thinking today as she walked alone up the lane back of the barn and then slowly down through the bottoms
# p:so for the hundredh time she was thinking to day as she walked alone up the lane back of the barn and then slowly down through the bottoms
# 63: WER: 0.00724637681159, DURATION: 8.77, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1826/1995-1826-0013.wav
# batch mean WER: 0.050477022807

# %%
res = evaluate(test_generator(datagen, test_samples, normalize=True), output_fn, beam_width=27, use_lm=True)
# Out:
# r:poyser is not at home is he
# p:poisoris not at home asse
# 0: WER: 0.192307692308, DURATION: 2.21, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0047.wav
# r:this missus poyser said blushing and believing that the captain was really interested in her milk pans and would adjust his opinion of her to the appearance of her dairy
# p:this missus poisor said blushing and believing that the captain was really interested in her miutpans and would edjust his opinion of her to the appearance of her dairy
# 1: WER: 0.0326409495549, DURATION: 10.01, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0059.wav
# r:then is the time to introduce a meal on the stage
# p:then is the time to entroduce a meal on the stage
# 2: WER: 0.0204081632653, DURATION: 2.86, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/92135/7176-92135-0037.wav
# r:at tea time they were sad and silent and the meal went away untouched by any of the three
# p:and ti time they were sad and silent and the meal went away and touched by any of the three
# 3: WER: 0.0555555555556, DURATION: 4.915, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0051.wav
# r:who began the quarrel was it the mormons
# p:who began the quarrel was at the mormonts
# 4: WER: 0.037037037037, DURATION: 2.92, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13751/4077-13751-0019.wav
# r:dear me what a chatterbox you're getting to be unc remarked the magician who was pleased with the compliment
# p:de me one o chater boxer getting to be unk remarked them agician who was pleased with the compliment
# 5: WER: 0.134615384615, DURATION: 6.73, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1181/1284-1181-0020.wav
# r:it would have been more wonderful had he spoken without a bidding
# p:it would have been more wonderful at he spoken without a bidding
# 6: WER: 0.0232558139535, DURATION: 3.88, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122612/1320-122612-0009.wav
# r:when the music by its bursts of melody carried away these illustrious dancers when the simple untutored pantomime of that period only the more natural on account of the very indifferent acting of the august actors had reached its culminating point of triumph the theater shook with tumultuous applause
# p:when the music by its bursts of melody carried away these elestrious dancers when the simple untutored pantamine of that period only the more natural on account of the vary endifferent acting of the augustactors had reached its comminating point of triumph the theater shook with tumultuous applause
# 7: WER: 0.03, DURATION: 20.15, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75946/7127-75946-0026.wav
# r:when she perceived the young man she rose like a woman surprised in the midst of ideas she was desirous of concealing from herself
# p:when she peroceived the young man she rose like a womans surprised and the bidst of ideas she was desirous of concealing from herself
# 8: WER: 0.0266159695817, DURATION: 8.865, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75947/7127-75947-0010.wav
# r:i'm glad you like it says wylder chuckling benignantly on it over his shoulder
# p:i'm glad you would like it says wilder chuckling tendignantly on it over his shoulder
# 9: WER: 0.0674846625767, DURATION: 6.065, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32865/5683-32865-0007.wav
# r:yes something everything said rachel hurriedly looking frowningly at a flower which she was twirling in her fingers
# p:yes something everything said rachel hearidly looking frowningly out a flower which she was towirling in her fingers
# 10: WER: 0.038961038961, DURATION: 8.405, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32879/5683-32879-0014.wav
# r:a pretty girl and so far as i could judge by appearances a good girl too describing her generally i may say that she had a small head well carried and well set on her shoulders bright gray eyes that looked at you honestly and meant what they looked a trim slight little figure too slight for our english notions of beauty a strong american accent and a rare thing in america a pleasantly toned voice which made the accent agreeable to english ears
# p:a pretty girl ans o far as i could judge by appearances a good crel to describing her generally i may say that she had a small head well carried ind well set endhe shoulders foright grey eyes that looked at you honestly and meant what they looked a trim light little figure to slight for english notions of beauty a strong american acdent and a ratthing in america a pleasantly tone voice which made the accent agreable to english years
# 11: WER: 0.0419026047565, DURATION: 25.415, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/36377/5142-36377-0014.wav
# r:in this guise it becomes horrible
# p:in this skies it becomes horrible
# 12: WER: 0.134328358209, DURATION: 3.885, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0038.wav
# r:i must come another day and see your husband i want to have a consultation with him about horses
# p:i must come another day and see your husband i want to have a consultation with him about horses
# 13: WER: 0.0, DURATION: 6.53, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0052.wav
# r:but don't these very wise things sometimes turn out very foolishly
# p:the ton't these very wise things sometimes turned out very foolishly
# 14: WER: 0.0814814814815, DURATION: 5.125, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32866/5683-32866-0002.wav
# r:what is slang
# p:what is sling
# 15: WER: 0.0769230769231, DURATION: 2.135, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0004.wav
# r:instead of shoes the old man wore boots with turnover tops and his blue coat had wide cuffs of gold braid
# p:instead of shoes the old man wore boots with turn over tops and is blue coat had wide cuffs of gold braide
# 16: WER: 0.0142180094787, DURATION: 7.68, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1180/1284-1180-0002.wav
# r:edison was intolerant of sham and shoddy and nothing would satisfy him that could not stand cross examination by microscope test tube and galvanometer
# p:atisan was entolterant of sharman shoddy and nothing would satisfy him that could not stand cross examination by microscope test tobe and galvanomener
# 17: WER: 0.06, DURATION: 11.145, PATH: /mnt/ml-data/LibriSpeech/test-clean/2300/131720/2300-131720-0012.wav
# r:the army found the people in poverty and left them in comparative wealth
# p:the army found the people im poverty and left them and comparative wealth
# 18: WER: 0.0344827586207, DURATION: 4.78, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13754/4077-13754-0000.wav
# r:solon marvelled and desired to be informed of the particulars
# p:solemn marveled and desire to be informed of the particulars
# 19: WER: 0.0413223140496, DURATION: 5.12, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/961/2961-961-0013.wav
# r:please forgive me for this underhanded way of admitting i had turned forty
# p:these forgive me for this underhanded play of admitting at i had turned forty
# 20: WER: 0.0728476821192, DURATION: 4.905, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/294828/8463-294828-0012.wav
# r:he could wait no longer
# p:he could wait no longer
# 21: WER: 0.0, DURATION: 2.085, PATH: /mnt/ml-data/LibriSpeech/test-clean/1089/134691/1089-134691-0000.wav
# r:when bartley arrived at bedford square on sunday evening marie the pretty little french girl met him at the door and conducted him upstairs
# p:when bartley arrived at but fort square on sunday evening mareed the pretty little french girl methim at the door and conducted him upstairs
# 22: WER: 0.0394265232975, DURATION: 7.835, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2273/4446-2273-0003.wav
# r:and thee won't go why should i
# p:and the wol't go why should i
# 23: WER: 0.0508474576271, DURATION: 3.83, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29095/4970-29095-0025.wav
# r:so uncas you had better take the lead while i will put on the skin again and trust to cunning for want of speed
# p:so uncus hou had better take the lead while i will put on the skin again and trust to cunnings for want of speed
# 24: WER: 0.0224215246637, DURATION: 6.36, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0025.wav
# r:there seems no good reason for believing that it will change
# p:there seems no good reason for believing that it will change
# 25: WER: 0.0, DURATION: 4.12, PATH: /mnt/ml-data/LibriSpeech/test-clean/2300/131720/2300-131720-0006.wav
# r:do we really know the mountain well when we are not acquainted with the cavern
# p:do we really know the mountain well when we are not acquainted with the cavern
# 26: WER: 0.0, DURATION: 5.545, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0033.wav
# r:yes the character which your royal highness assumed is in perfect harmony with your own
# p:yes the character which you are royal highness assumed is in perfect harmony with your own
# 27: WER: 0.0169491525424, DURATION: 5.98, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75947/7127-75947-0003.wav
# r:the air is heavy the sea is calm
# p:the air is heavy the sea is calm
# 28: WER: 0.0, DURATION: 4.31, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123288/260-123288-0004.wav
# r:i see a crowd in one corner of the garden everybody standing still and looking up
# p:i see a crowd and one corner of the garden everybody standing stiln looking up
# 29: WER: 0.0440251572327, DURATION: 5.515, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0024.wav
# r:that is true badauderie
# p:that is true baddoth grye
# 30: WER: 0.25, DURATION: 3.0, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0027.wav
# r:pack as much into my trunk as you can my traveling kit my suits shirts and socks don't bother counting just squeeze it all in and hurry
# p:pack as much into my trunk as you can but thavelling kit my soits sharts and sacks don't byther counting just squeeze it all in and hurry
# 31: WER: 0.0588235294118, DURATION: 9.3, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/294828/8463-294828-0017.wav
# r:to ask any more questions of you i believe would be unfair
# p:to ask any more questions of you i believe would be unfair
# 32: WER: 0.0, DURATION: 4.045, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/23283/4992-23283-0007.wav
# r:why are we to be denied each other's society
# p:where we to be denied each other society
# 33: WER: 0.0714285714286, DURATION: 2.99, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0001.wav
# r:proscribed by the civil and ecclesiastical powers of the empire the donatists still maintained in some provinces particularly in numidia their superior numbers and four hundred bishops acknowledged the jurisdiction of their primate
# p:proscribed why the sivil andacclesiastical powers of the empire the downitist still mantained in some provinces particularly indominia there superior numbers and four hundred bishop's acknowledge the juristiction of their primate
# 34: WER: 0.0608695652174, DURATION: 14.17, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/134647/1284-134647-0007.wav
# r:alexander groaned i meant to but somehow i couldn't
# p:alexanderground i meant to but somehow i couldn't
# 35: WER: 0.04, DURATION: 3.805, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0023.wav
# r:he knows them both
# p:he knows them but
# 36: WER: 0.0857142857143, DURATION: 1.915, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0030.wav
# r:before the settlement of terms the administration must be possessed entirely by the parliaments of both kingdoms and how incompatible that scheme with the liberty of the king is easily imagined
# p:before the settlement of terms the administration must be possessed in tirely by the parliaments of both kingdoms and how incompatible that scheme with the liberty of the king is easily imagined
# 37: WER: 0.0077519379845, DURATION: 14.6, PATH: /mnt/ml-data/LibriSpeech/test-clean/8224/274384/8224-274384-0010.wav
# r:and what sort of evidence is logically possible
# p:and what sort of evidence is logically possible
# 38: WER: 0.0, DURATION: 3.195, PATH: /mnt/ml-data/LibriSpeech/test-clean/8230/279154/8230-279154-0003.wav
# r:moreover had the people been inclined to rebellion what greater opportunity could they have wished
# p:moreover had the people been inclined to rebellion won' gaiter opportunity could they have wished
# 39: WER: 0.0564102564103, DURATION: 5.68, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13754/4077-13754-0003.wav
# r:the child had a native grace which does not invariably co exist with faultless beauty its attire however simple always impressed the beholder as if it were the very garb that precisely became it best
# p:the child had a native grace which does not embarryably co exist with foultless beauty its a tire however simple always impressed the behoder as if it were the very guarb that precisely became it basts
# 40: WER: 0.045, DURATION: 13.72, PATH: /mnt/ml-data/LibriSpeech/test-clean/1221/135766/1221-135766-0003.wav
# r:she then rose humming the air to which she was presently going to dance
# p:she then rose humming the air to which she was presently going to dance
# 41: WER: 0.0, DURATION: 5.46, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75947/7127-75947-0007.wav
# r:they say illumination by candle light is the prettiest in the world
# p:they say allumination by ckandle iht is the prettiest in the world for
# 42: WER: 0.0656934306569, DURATION: 4.05, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/76324/6930-76324-0024.wav
# r:it is to let hamlet if that happen to be the name of your character enter with a small dog pet falcon mongoose tame bear or whatever animal is most in keeping with the part and confide in this animal such sorrows hopes or secret history as the audience has got to know
# p:it is to let hamlet if that happened to be they nameo your character intervole small dog pet falcon mong tos tamebear or dever animal is most enkeeping with the part and confide in this animal such sorrows hopes or secret history as the audiouce has got to now
# 43: WER: 0.0681818181818, DURATION: 15.74, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/92135/7176-92135-0025.wav
# r:it was on the last day of january that the repairs of the schooner were completed
# p:it was on the last day of january that the repairs of the schooner were completed
# 44: WER: 0.00613496932515, DURATION: 4.725, PATH: /mnt/ml-data/LibriSpeech/test-clean/5105/28240/5105-28240-0022.wav
# r:on she hurried until sweeping down to the lagoon and the island lo the cotton lay before her
# p:ant yhe hurried until sweeping down to the lagoon and the island low the cotton laborfore her
# 45: WER: 0.0702702702703, DURATION: 6.705, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1837/1995-1837-0027.wav
# r:truly this sea is of infinite width
# p:truly vese is of infinite with
# 46: WER: 0.138461538462, DURATION: 2.98, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123286/260-123286-0014.wav
# r:nothing can exceed the beauty or art of the introduction in which he is using words after his accustomed manner
# p:nothing can exceed the beauty or art of thintroduction in which hes using words after his accustomed manner
# 47: WER: 0.0183486238532, DURATION: 7.87, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/960/2961-960-0017.wav
# r:i give my consent
# p:i gave my consent
# 48: WER: 0.0588235294118, DURATION: 2.44, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75947/7127-75947-0036.wav
# r:yes my dear watson i have solved the mystery
# p:yes my dear watson i have solved the mystery
# 49: WER: 0.0, DURATION: 3.125, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141084/1580-141084-0019.wav
# r:no one saw him do this for all were looking at the powder of life but soon the woman remembered what she had been doing and came back to the cupboard
# p:no one saw him do this for all were looking at the powder of life but soon the woman remembered what she had been doing and came back to the cupboard
# 50: WER: 0.0, DURATION: 8.51, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1181/1284-1181-0012.wav
# r:cyril there must be some better way of doing i just draw the outline of an animal and then i put hairs or feathers on it they have no bodies
# p:caral there must be some better way b doing i just traw the autline of an animal and that i put hars or feathers on it they have no bodies
# 51: WER: 0.0575539568345, DURATION: 8.65, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/41797/4992-41797-0015.wav
# r:what of the farm olaf not yet i answered viking is better for summer
# p:what of the farmold lof not yet i answered byking is better for summer
# 52: WER: 0.0935251798561, DURATION: 4.77, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0022.wav
# r:it takes me several years to make this magic powder but at this moment i am pleased to say it is nearly done you see i am making it for my good wife margolotte who wants to use some of it for a purpose of her own
# p:it takes me sevral years to make this magic powder but at this moment i am pleased to say it is nearly done you see i making it for my good wife margolot who ants to use some of it for a purpose of her own
# 53: WER: 0.0167865707434, DURATION: 12.005, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1180/1284-1180-0018.wav
# r:one thinks one hears hydras talking
# p:one things one heres highdress talking
# 54: WER: 0.178082191781, DURATION: 3.925, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0040.wav
# r:i don't want to stand around and look on
# p:i don't want to stand around of no on
# 55: WER: 0.116883116883, DURATION: 2.065, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/134500/237-134500-0029.wav
# r:their contents had all boiled away leaving in the bottom of each kettle a few grains of fine white powder
# p:there contents had allboiled away leaving in the bottom of each cattle a few grains of fine white powder
# 56: WER: 0.0430622009569, DURATION: 6.435, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1181/1284-1181-0010.wav
# r:since christ was given for our sins it stands to reason that they cannot be put away by our own efforts
# p:since christ was given for our sins e stands to reason that they colnot be put away by arown efforts
# 57: WER: 0.0541871921182, DURATION: 6.085, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0066.wav
# r:cries of a nottingham a nottingham
# p:cries of anottingham an nottingham
# 58: WER: 0.0294117647059, DURATION: 2.61, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0012.wav
# r:i doubt whether branwell was maintaining himself at this time
# p:i don't whether branwell was maintaining himself at the time
# 59: WER: 0.0578512396694, DURATION: 3.3700625, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0056.wav
# r:we are quite satisfied now captain battleax said my wife
# p:we are quite satisfied now captain battle as said my wife
# 60: WER: 0.0265486725664, DURATION: 4.52, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0006.wav
# r:and meantime i know the greatness of jehovah i acknowledge the perfection of his word i adore the purity of the christian faith my theory is right my practice horribly wrong
# p:and meantime i know the greatness of jehova i hacknowlege the prfection of his word i adore the peerity of the chrishian faith my theory is right my practice horribly rong
# 61: WER: 0.0290697674419, DURATION: 11.535, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0038.wav
# r:my pursuits are peaceful and my temper i humbly trust is greatly given to mercy and love returned david a little nettled at so direct an attack on his manhood but there are none who can say that i have ever forgotten my faith in the lord even in the greatest straits
# p:my pursuits are peaceful en my temper i humbly trust is greatly given to mercy and love returned david a little nettle that so direct and attack on his manhood but there are none who can say that i have ever forgotten my faith in the lord even in the greatest strahts
# 62: WER: 0.0206378986867, DURATION: 15.995, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0028.wav
# r:and he added something still less complimentary
# p:and he added something still less complimentary
# 63: WER: 0.0, DURATION: 3.47, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32866/5683-32866-0001.wav
# batch mean WER: 0.0502432882341
# r:the king's ears were now open to montrose's counsels who proposed none but the boldest and most daring agreeably to the desperate state of the royal cause in scotland
# p:the kings ears were now open to montroses councels who proposed none but the boldest and most daring agreeably to the desperate state of the royal cause in scotland
# 0: WER: 0.0121212121212, DURATION: 13.085, PATH: /mnt/ml-data/LibriSpeech/test-clean/8224/274381/8224-274381-0003.wav
# r:in other words these three men took down the lectures which luther addressed to his students in the course of galatians and roerer prepared the manuscript for the printer
# p:an other words these three men took down the lectures which lotheradressed to his tents in the course of glations and roar prepared the manuscript for the princer
# 1: WER: 0.0542168674699, DURATION: 9.44, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3979/2830-3979-0008.wav
# r:had eva crasweller not been good looking had jack been still at college had sir kennington oval remained in england had mister bunnit and the bar keeper not succeeded in stopping my carriage on the hill should i have succeeded in arranging for the final departure of my old friend
# p:had h ete cruss weller not been god luoking had jack been still at college had cir kenninton avel remained in angland and mister bunnet and the bar keeper not succeeded and stopping my carriage on the hill should i have succeeded in arragian for the final departure of my eld friend
# 2: WER: 0.067615658363, DURATION: 18.125, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0001.wav
# r:philip lefrank this is my overlooker mister jago said the old man formally presenting us
# p:fill up a rang this is my overlooker mister yargo said the old man formerly presenting us
# 3: WER: 0.129943502825, DURATION: 5.14, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/36377/5142-36377-0009.wav
# r:no thanks i am glad to give you such easy happiness
# p:now tanks i am glad to give you such easy happiness
# 4: WER: 0.0196078431373, DURATION: 3.735, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0060.wav
# r:the fireball half of it white half azure blue and the size of a ten inch shell moved slowly about the raft but revolving on its own axis with astonishing velocity as if whipped round by the force of the whirlwind
# p:the fir ball half of it white half azerblue and the size of atten in shill moved solly about the raft but revolving on its own acxis with a stonishing philocity as if whpp round by the force of the worlwind
# 5: WER: 0.066985645933, DURATION: 14.595, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123288/260-123288-0024.wav
# r:my first and principal reason was that they enforced beyond all resistance on any student who might attempt to copy them this method of laying portions of distinct hue side by side
# p:my first inprincipal reason was that they inforced beyond all resistance on any student who ight attempt a copy them this method of layng portons of distinct huge side by side
# 6: WER: 0.0366197183099, DURATION: 12.61, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0003.wav
# r:and why it scatters its bright beauty thro the humid air
# p:and why scatters its bright beauty through the humidair
# 7: WER: 0.0630630630631, DURATION: 4.315, PATH: /mnt/ml-data/LibriSpeech/test-clean/908/157963/908-157963-0013.wav
# r:for one long moment he paused stupid agape with utter amazement then leaned dizzily against a tree
# p:for one long moment he paused stopid agap withutter amazement then len diszily against the trees
# 8: WER: 0.0721649484536, DURATION: 7.19, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1837/1995-1837-0016.wav
# r:how is it la valliere said mademoiselle de tonnay charente that the vicomte de bragelonne spoke of you as louise
# p:how is it lovalier said mademoiselle detenisiat that o icomfrtabragalone spoke of you as louise
# 9: WER: 0.188405797101, DURATION: 8.865, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75947/7127-75947-0033.wav
# r:i get tired of seeing men and horses going up and down up and down
# p:i get tired of seeing man and horses going up un down up undown
# 10: WER: 0.0697674418605, DURATION: 5.025, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/134500/237-134500-0032.wav
# r:i hope thee told the elders that father and i are responsible for the piano and that much as thee loves music thee is never in the room when it is played
# p:i hope the told the elders that father and irisponsible for the piano and that much as the loves music the ise never in the room when it is played
# 11: WER: 0.0367892976589, DURATION: 10.02, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29095/4970-29095-0003.wav
# r:you will forgive me dear reader if i have made you attend the funeral of silvia ten years before her death believe me i have no intention of performing a miracle you may console yourself with the idea that i shall spare you that unpleasant task when poor silvia dies
# p:you will forgive me dear meater if i have made to attend the funeral of sylvia attenyears before her death believe me i have no intention of performing amiracle you may console yourself with the idea that i shall spare you that unpleasant task wen poor sylvia dies
# 12: WER: 0.0301886792453, DURATION: 18.31, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0009.wav
# r:he planted a company before the hotel and demanded a surrender of the arms belonging to the free state military companies
# p:he planted a company before the hotel and demanded a surrender of the arms belonging to the free state military companies
# 13: WER: 0.0, DURATION: 7.705, PATH: /mnt/ml-data/LibriSpeech/test-clean/7729/102255/7729-102255-0036.wav
# r:the john bright is armed with a weapon of great power against which it is impossible that the people of britannula should prevail
# p:the jam breght as arm with a weapon of great power against which it is impossible that the people of britain yulushould prevail
# 14: WER: 0.0703125, DURATION: 7.075, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0060.wav
# r:above were three students one on each story
# p:above re three students one on each story
# 15: WER: 0.0352941176471, DURATION: 2.705, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141083/1580-141083-0019.wav
# r:now then let's enter the city an enjoy the grand feast that's being cooked i'm nearly starved myself for this conquerin kingdoms is hard work
# p:now then lets enter the city and enjoy the great feast its being cout i nearly starmyself for this congreen kingdoms as hard work
# 16: WER: 0.125925925926, DURATION: 9.31, PATH: /mnt/ml-data/LibriSpeech/test-clean/8555/284449/8555-284449-0007.wav
# r:in the present day we are well aware that an ancient philosopher is to be interpreted from himself and by the contemporary history of thought
# p:in the present day we are well a wear but an incient philosopher is to be intripurted from himself and by the contemporary history of thought
# 17: WER: 0.063829787234, DURATION: 10.355, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/960/2961-960-0005.wav
# r:listen then socrates to a tale of solon's who being the friend of dropidas my great grandfather told it to my grandfather critias and he told me
# p:listenben so cretys to a tail of solence who being the friend of dropides mik great grandfather told it to my grandfather credeous and he told me
# 18: WER: 0.114186851211, DURATION: 11.48, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/961/2961-961-0004.wav
# r:but anders cared nothing about that
# p:but ander's care nothing about that
# 19: WER: 0.0285714285714, DURATION: 3.02, PATH: /mnt/ml-data/LibriSpeech/test-clean/7021/85628/7021-85628-0000.wav
# r:the greeting of the apostle is refreshing
# p:the greeting of the apostles werefreshen
# 20: WER: 0.135802469136, DURATION: 2.62, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0040.wav
# r:i will if timaeus approves i approve
# p:i will if to me as a pruves i approove
# 21: WER: 0.189189189189, DURATION: 4.73, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/961/2961-961-0003.wav
# r:it seems to me i replied that such approval such ratification of the opinion expressed by the king the princes of the blood et cetera is rather a proof of the affection felt for them by the nation for the french carry that affection to such an extent that they believe them infallible
# p:it seems to me i replied that such a croval such ratification of the opinion expressed by the king the princes of the blood at cetera is rather epproof of the effection felt for them by the nation for the french carry that affection to such an extent that they believe them in fallible
# 22: WER: 0.0228471001757, DURATION: 20.65, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0035.wav
# r:mussulmans and giaours throw kerchiefs at a smile and have no ruth for any weeping
# p:musclemens and guyors through cerchets and a smile and havf no rot for any weeping
# 23: WER: 0.182926829268, DURATION: 7.795, PATH: /mnt/ml-data/LibriSpeech/test-clean/908/31957/908-31957-0017.wav
# r:he keeps the thou shalt not commandments first rate hen lord does
# p:he keeps thet thou shaut not commandents first ray hen lord does
# 24: WER: 0.0542635658915, DURATION: 4.55, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/41797/4992-41797-0006.wav
# r:no sir certainly not
# p:no sir certainly not
# 25: WER: 0.0, DURATION: 3.36, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141084/1580-141084-0027.wav
# r:the late astounding events however had rendered procope manifestly uneasy and not the less so from his consciousness that the count secretly partook of his own anxiety
# p:the lateestonding events however had rendered procope menifastly uneasy and not the less sol from his consciousness that the count secretly partook of his own anxiety
# 26: WER: 0.0299401197605, DURATION: 10.96, PATH: /mnt/ml-data/LibriSpeech/test-clean/5105/28241/5105-28241-0002.wav
# r:in novels the hero has often pushed his meals away untasted but no stage hero would do anything so unnatural as this
# p:and novels the hero his often pushed his meals away untasted but noestedisura would do anything so anatural as this
# 27: WER: 0.0995670995671, DURATION: 7.27, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/92135/7176-92135-0042.wav
# r:what the latter day saints call celestial marriage is characteristic of the church and is in very general practise but of celestial marriage plurality of wives was an incident never an essential
# p:what a letter ney sades calls oless chal marriage is characteristic up the church and is invery general practice but of selistial marriage plurality of wie's was an incident never and ecential
# 28: WER: 0.119170984456, DURATION: 12.7499375, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13754/4077-13754-0006.wav
# r:thel is like a watry bow and like a parting cloud like a reflection in a glass like shadows in the water like dreams of infants like a smile upon an infants face
# p:fell is like a wathery bow and like a parting cloud like a reflection in a glance wike shadows in the water like dreams of infants like a smile upon it infints face
# 29: WER: 0.0646153846154, DURATION: 13.99, PATH: /mnt/ml-data/LibriSpeech/test-clean/908/157963/908-157963-0004.wav
# r:the democratic committee figured out a way to do this
# p:the democratic committee figured out away to do this
# 30: WER: 0.00952380952381, DURATION: 4.015, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68771/6829-68771-0003.wav
# r:he had a lot of line out and the place was none too free for a long cast but he was impatient to drop his flies again on the spot where the big fish was feeding
# p:he had a lot of line out and the place was none to free for a long cast but he was impatient to drop his flies again on the spot where the big fish was feeding
# 31: WER: 0.00313479623824, DURATION: 9.645, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/88083/7176-88083-0023.wav
# r:thank you rachel my cousin rachel my only friend
# p:think you rachel my cousin recha my only friend
# 32: WER: 0.0736842105263, DURATION: 4.38, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32879/5683-32879-0012.wav
# r:a cold bright moon was shining with clear sharp lights and shadows
# p:a cold bright moon was shining with clear sharp light and shadows
# 33: WER: 0.00763358778626, DURATION: 4.755, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32866/5683-32866-0027.wav
# r:to such persons these indirect modes of training children in habits of subordination to their will or rather of yielding to their influence are specially useful
# p:to such persons these interect modes of training children inhabits of subordination to their will or rather of yielding to their influence are specially useful
# 34: WER: 0.0156739811912, DURATION: 11.125, PATH: /mnt/ml-data/LibriSpeech/test-clean/7021/79740/7021-79740-0000.wav
# r:experience proves this
# p:experience proves this
# 35: WER: 0.0, DURATION: 1.975, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0043.wav
# r:all that i am doing is to use its logical tenability as a help in the analysis of what occurs when we remember
# p:all that i am doing is to use its lodgical tenability as a help in the analysis of what occurs when we remember
# 36: WER: 0.00452488687783, DURATION: 7.72, PATH: /mnt/ml-data/LibriSpeech/test-clean/8230/279154/8230-279154-0005.wav
# r:it may be that a great colorist will use his utmost force of color as a singer his full power of voice but loud or low the virtue is in both cases always in refinement never in loudness
# p:it may be that a great color is will use his utmost force of collar as a singer his full power of voice but loud orlottl the virtue is in both cases always in refinement never in loudness
# 37: WER: 0.0268817204301, DURATION: 14.65, PATH: /mnt/ml-data/LibriSpeech/test-clean/1188/133604/1188-133604-0012.wav
# r:watson i have always done you an injustice there are others
# p:whats a i have always done you and enjustice there are others
# 38: WER: 0.0666666666667, DURATION: 4.135, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141083/1580-141083-0032.wav
# r:to the fervent latter day saint a temple is not simply a church building a house for religious assembly
# p:to the fervant latterday saint attemple is not simply aturch building a house farelidious assembly
# 39: WER: 0.0746268656716, DURATION: 6.72, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13751/4077-13751-0010.wav
# r:thinks i to myself i never seen anything osh popham couldn't mend if he took time enough and glue enough so i carried this little feller home in a bushel basket one night last month an i've spent eleven evenin's puttin him together
# p:thinks sad of myself im never seen anything ished papla good and man if he took time enogh and glowenug so i carried this little feller howm an a bush obesqk at one night lass mop and i've spent a laven evenand sput in him together
# 40: WER: 0.177489177489, DURATION: 15.21, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/41806/4992-41806-0014.wav
# r:mindful however of her own errors and misfortunes she early sought to impose a tender but strict control over the infant immortality that was committed to her charge
# p:mindful however of her own errors and misfortunes she early sought to impose attender but strict control over the infant in mortality that was the committed to her charge
# 41: WER: 0.0268656716418, DURATION: 10.78, PATH: /mnt/ml-data/LibriSpeech/test-clean/1221/135766/1221-135766-0008.wav
# r:oh let him come along she urged i do love to see him about that old house
# p:oh let him come along she urged i de lock to see him about that old house from
# 42: WER: 0.0728476821192, DURATION: 5.41, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/76324/6930-76324-0017.wav
# r:this person was rodolfo who though he had gone to look for his friends had changed his mind in that respect not thinking it advisable to acquaint them with what had passed between him and the girl
# p:this person was redullful with a we had gone to look for his friends had changed his mind and that prespect nothinging it advisable to acquaint tem but what had passed between him and the girl
# 43: WER: 0.0876288659794, DURATION: 11.02, PATH: /mnt/ml-data/LibriSpeech/test-clean/5639/40744/5639-40744-0015.wav
# r:nay we refused their request most politely most noble said the little stroller
# p:nay we refresed their request most politely most noble said the little stroller
# 44: WER: 0.0191082802548, DURATION: 5.375, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0015.wav
# r:therefore don't talk to me about views and prospects
# p:therefore don't talk to me about views and prospects
# 45: WER: 0.0, DURATION: 3.735, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123286/260-123286-0008.wav
# r:that is all quite true mister neverbend said sir ferdinando brown
# p:that is all quite true mister negberben said sir ferdin and obrown
# 46: WER: 0.0687022900763, DURATION: 4.99, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0035.wav
# r:you are a worthy leech will presently whispered robin the wine has worked a marvel
# p:you are  worthy leach will presently whispered robin the wine as worked a marvel
# 47: WER: 0.0246913580247, DURATION: 5.53, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0061.wav
# r:liter roughly one quart
# p:leader roughly one court
# 48: WER: 0.25, DURATION: 2.35, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/294825/8463-294825-0017.wav
# r:once in action he was leading a detachment of infantry through an intrenchment
# p:once and action he was leading a detachment of imfantry through an intrenchment
# 49: WER: 0.031847133758, DURATION: 4.735, PATH: /mnt/ml-data/LibriSpeech/test-clean/5105/28233/5105-28233-0004.wav
# r:he's another who's awfully keen about her let me introduce you
# p:hes another whos owfully keen about her let me introduce you
# 50: WER: 0.0327868852459, DURATION: 3.135, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2271/4446-2271-0010.wav
# r:my scholar has been left very poor but he is hard working and industrious he will do well
# p:my scholar has been left very poor but he is hard working and industrious he will do well
# 51: WER: 0.0, DURATION: 5.865, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141083/1580-141083-0042.wav
# r:at the edge of this box there lies a great wooden doll which so far as mutilation is concerned bears a strong resemblance to the finest greek sculpture and especially in the total loss of its nose
# p:at the edge of this pox their lies a great wooden oll which so mar as mutilation is concern bears a strong resemblance to the finest greek sculpture and especially in the total loss of its nose
# 52: WER: 0.0282776349614, DURATION: 13.82, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0006.wav
# r:he stood a moment bewildered then turned and rushed upon the island a great sheet of dazzling sunlight swept the place and beneath lay a mighty mass of olive green thick tall wet and willowy
# p:he stood a moment be wildered then turned and rushed upon the island a great sheet of dazzling sunlight swept the place and beneath lay a mighty mass of ollie green they tall wet and willaway
# 53: WER: 0.0341207349081, DURATION: 12.46, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1837/1995-1837-0014.wav
# r:will the hurons hear his groans
# p:will theherens here his groans
# 54: WER: 0.147540983607, DURATION: 2.24, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0038.wav
# r:scuse me said trot i neglected to tell you that you're not the boolooroo any more
# p:scuse me said chot id negleted to tell you that youre not the boolooroo any more
# 55: WER: 0.0434782608696, DURATION: 5.775, PATH: /mnt/ml-data/LibriSpeech/test-clean/8555/284449/8555-284449-0013.wav
# r:the drag upon his beak and the light check upon his wings were inexplicable to him and appalling
# p:the drag upon his beak and the light check upon his wings were inexplicable to him and uhalling
# 56: WER: 0.0261780104712, DURATION: 5.53, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/88083/7176-88083-0026.wav
# r:no one less than that would have a chance
# p:no one less than that would have a chance
# 57: WER: 0.0120481927711, DURATION: 2.955, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141084/1580-141084-0038.wav
# r:why you said to fetch the first living creature we met and that was this billygoat replied the captain panting hard as he held fast to one of the goat's horns
# p:why you sit to veceta fersliving cretue met and that was the sbligote replied the captain panting hord as he held first to one of the goats whorns
# 58: WER: 0.138157894737, DURATION: 9.04, PATH: /mnt/ml-data/LibriSpeech/test-clean/8555/284447/8555-284447-0013.wav
# r:remembering has to be a present occurrence in some way resembling or related to what is remembered
# p:remembering has to be a present occurrence and some way resembling or lated to what is remembered
# 59: WER: 0.025641025641, DURATION: 6.56, PATH: /mnt/ml-data/LibriSpeech/test-clean/8230/279154/8230-279154-0021.wav
# r:onward said a distant voice
# p:awur said a distant voice
# 60: WER: 0.132075471698, DURATION: 3.305, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/81414/6930-81414-0002.wav
# r:what shall we do with the mingoes at the door they count six and this singer is as good as nothing
# p:what shall we do with the mingoes at the door they count six and the singer as as good as nothing
# 61: WER: 0.025641025641, DURATION: 5.335, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0021.wav
# r:weren't you happy then at all
# p:worn't you happy then at all
# 62: WER: 0.0526315789474, DURATION: 2.16, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0025.wav
# r:there befell an anxious interview mistress fitzooth arguing for and against the squire's project in a breath
# p:there be fell an anxious interview mistress fitzhreoth arguing four ignd against the squire's project in a breath
# 63: WER: 0.0407239819005, DURATION: 6.155, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70970/61-70970-0001.wav
# batch mean WER: 0.0619494639663
# r:the delawares are children of the tortoise and they outstrip the deer
# p:the delawares are children of the tortis and the outstripped the deer
# 0: WER: 0.0434782608696, DURATION: 3.855, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0022.wav
# r:their distinctive characters however display one broad and unfailing difference
# p:there it istinctive characters however display one broad and unfailing difference
# 1: WER: 0.05, DURATION: 5.5, PATH: /mnt/ml-data/LibriSpeech/test-clean/7729/102255/7729-102255-0023.wav
# r:the genealogies which you have recited to us out of your own annals solon are a mere children's story
# p:the genialogies which wu have recited thil earts out of your own annal solen i emuwed children story
# 2: WER: 0.164179104478, DURATION: 7.815, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/961/2961-961-0011.wav
# r:luis was out of danger in a fortnight in a month he rose from his bed and during all that time he was visited daily by his mother and grandmother and treated by the master and mistress of the house as if he was their own child
# p:who as was out of danger in a fortnight and a month he rose from his bed and drewing all that time he was visited daily by his mother and grandmother and treated by the master and mistress of the house as if he was their own child
# 3: WER: 0.0350877192982, DURATION: 14.5, PATH: /mnt/ml-data/LibriSpeech/test-clean/5639/40744/5639-40744-0026.wav
# r:i believe it sir and that is what i fear therefore the principal object of my visit here is to devote myself entirely to the study of the french language
# p:i believe it sir and that is what i fear therefore the principal object of my visitere is to devote myself entirely to the study of the french flanguage
# 4: WER: 0.00983606557377, DURATION: 10.895, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0041.wav
# r:at the head of the pinkies were ghip ghisizzle and button bright who had the parrot on his shoulder and they were supported by captain coralie and captain tintint and rosalie the witch
# p:at the head of the pinkies were get gissesl and but embright who had the pyro on his shoulder and there were supported by keptain correle and captain tintant and rosaly the witch
# 5: WER: 0.116022099448, DURATION: 11.075, PATH: /mnt/ml-data/LibriSpeech/test-clean/8555/284449/8555-284449-0002.wav
# r:but in this friendly pressure raoul could detect the nervous agitation of a great internal conflict
# p:by in this friendly pressure row could detect the mivis agitation of a great internal conflict
# 6: WER: 0.0824742268041, DURATION: 6.16, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/75918/6930-75918-0017.wav
# r:so i lived and now am your tooth thrall well it is the luck of war
# p:so i lived an now am your twoth trall well it is the luck of war
# 7: WER: 0.0381679389313, DURATION: 4.235, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0068.wav
# r:of course the words this has existed before are a very inadequate translation of what actually happens when we form a judgment of recognition but that is unavoidable words are framed to express a level of thought which is by no means primitive and are quite incapable of expressing such an elementary occurrence as recognition
# p:of course the words this has existed before our af vairy inadequate translation of what actually happens when we form a judgment of recognition but that is unavoid able wheres are framed to express a levelo thought which is by no means permitive and are quite and capable of expressing such an elementary occurrence as it recognition
# 8: WER: 0.0440060698027, DURATION: 24.485, PATH: /mnt/ml-data/LibriSpeech/test-clean/8230/279154/8230-279154-0043.wav
# r:she had another weight on her mind this christmas
# p:she had another wat on her mind this christmas
# 9: WER: 0.0526315789474, DURATION: 3.0, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0052.wav
# r:all is said without a word
# p:all is said without a word
# 10: WER: 0.0, DURATION: 2.125, PATH: /mnt/ml-data/LibriSpeech/test-clean/908/31957/908-31957-0000.wav
# r:at another time harald asked
# p:at another time haroldasked
# 11: WER: 0.0714285714286, DURATION: 2.005, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0000.wav
# r:warrenton spoke thus with significance to show robin that he was not to think geoffrey's claims to the estate would be passed by
# p:warranton'spoke thus with senificance to show robin that he was not to think geffrey's claims to the estate wit be passed by
# 12: WER: 0.0555555555556, DURATION: 7.405, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70970/61-70970-0035.wav
# r:then you can ask him questions on the catechism dedalus
# p:then you can ask him questions on the catacasm deaalus
# 13: WER: 0.0642201834862, DURATION: 3.54, PATH: /mnt/ml-data/LibriSpeech/test-clean/1089/134686/1089-134686-0016.wav
# r:though i may be but an ungracious adviser you will allow me therefore to subscribe myself with the best wishes for your happiness here and hereafter your true friend robert southey
# p:though i may be but an angracious adviser you will allow me therefore to suscribe myself with the best wishes for e happiness here and here after your cheer friend robert sovee
# 14: WER: 0.061797752809, DURATION: 12.73, PATH: /mnt/ml-data/LibriSpeech/test-clean/3575/170457/3575-170457-0017.wav
# r:for it is a solid heavy handsome door and must once have been in the habit of shutting with a sonorous bang behind a liveried lackey who had just seen his master and mistress off the grounds in a carriage and pair
# p:for it is a solid heavy handsome door and must once have been in the habit of shudding with a sonerous baing behind the livery lackey who had gent seen his master and mistress off the grounds in a carriedge and par
# 15: WER: 0.0585480093677, DURATION: 15.52, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0002.wav
# ...
# r:does thee think thee could stand it six months
# p:this the think the could stand it six months
# 11: WER: 0.0888888888889, DURATION: 3.355, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29095/4970-29095-0011.wav
# r:assuredly if the tongue which a nation or a province has spoken is worthy of interest the language which has been spoken by a misery is still more worthy of attention and study
# p:a suredly if the tongue which anation or a province has spoken is worthy of interest the language which has been spoken by a misery is still more worthy of attention and study
# 12: WER: 0.00854700854701, DURATION: 14.79, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0030.wav
# r:she wanted a glance of the new books and periodicals and talk of great philanthropies and reforms
# p:she wanted a glance of the new books and periodicals and talk of greatful anthropies in beforms
# 13: WER: 0.0729166666667, DURATION: 6.18, PATH: /mnt/ml-data/LibriSpeech/test-clean/1995/1826/1995-1826-0012.wav
# r:he give up his position and shut the family up in that tomb of a house so t he could study his books
# p:they gave up his position as shut the family up in that tom of a house son he couldn't study his books
# 14: WER: 0.0693069306931, DURATION: 6.905, PATH: /mnt/ml-data/LibriSpeech/test-clean/4992/41797/4992-41797-0007.wav
# r:their assumed character changed with their changing opportunities or necessities
# p:there assumed character changed with their changing opportunities or necessities
# 15: WER: 0.025, DURATION: 5.485, PATH: /mnt/ml-data/LibriSpeech/test-clean/7729/102255/7729-102255-0025.wav
# r:i am stiff with long sitting he said i itch for a fight i turned to the farmer
# p:i'm stiff with long said in he said i e for our fighte i turned to the farmer
# 16: WER: 0.128205128205, DURATION: 4.855, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0044.wav
# r:american school boys read with emotions of horror of the albigenses driven beaten and killed with a papal legate directing the butchery and of the vaudois hunted and hounded like beasts as the effect of a royal decree and they yet shall read in the history of their own country of scenes as terrible as these in the exhibition of injustice and inhuman hate
# p:american schoolboyce read with emotions of horror of ealbagenses driven beaten and killed with a papple li aihe direct in the butchery and thof thathold oas hunted and how de like beasts as the effect of a real decree and they yet shall read in the history of their own country of seenes as terrible as these in the exhibition of enjustice and inhumant hate
# 17: WER: 0.0687237026648, DURATION: 26.115, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13751/4077-13751-0018.wav
# r:i suppose that's the wet season too then
# p:i suppose that's the wetceason to then
# 18: WER: 0.0512820512821, DURATION: 2.22, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/134500/237-134500-0009.wav
# r:i shan't trouble you about my train of thoughts or fancies but i began to feel very like a gentleman in a ghost story watching experimentally in a haunted chamber
# p:i sha'n't trouble you about my train of thoughts or vancies but i began to feel very like a gentleman and a gho story watching experimentally in a haunted chaver
# 19: WER: 0.0340557275542, DURATION: 9.855, PATH: /mnt/ml-data/LibriSpeech/test-clean/5683/32866/5683-32866-0024.wav
# r:she even seemed mildly amused at the attention she attracted
# p:she even seemed mildly amused at the attention she adtracted
# 20: WER: 0.0166666666667, DURATION: 3.555, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68771/6829-68771-0028.wav
# r:slow to world greetings quick with its o list when the angels speak
# p:slow to world greedings quick with it old let when the angels speak
# 21: WER: 0.0597014925373, DURATION: 6.18, PATH: /mnt/ml-data/LibriSpeech/test-clean/908/31957/908-31957-0013.wav
# r:ay and show you some pretty tricks
# p:i in shu you some pretty tricks
# 22: WER: 0.138461538462, DURATION: 2.555, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0062.wav
# r:i thought it might be sister kate or cousin mike would be happening along
# p:i thought it might be sistercatorcousin mike would be happening along
# 23: WER: 0.048951048951, DURATION: 3.54, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0006.wav
# r:they were received in the little office by a man named markham who was the jailer
# p:they were asaved in the little office by a man ne markum who was the jailer
# 24: WER: 0.0897435897436, DURATION: 4.22, PATH: /mnt/ml-data/LibriSpeech/test-clean/6829/68769/6829-68769-0009.wav
# r:you know him i think so
# p:you know him i think so
# 25: WER: 0.0, DURATION: 2.375, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141084/1580-141084-0025.wav
# r:already a north and a south were talked of why not set up also a west
# p:already inorth and  south were talke of why not set up alsobl west
# 26: WER: 0.0666666666667, DURATION: 4.985, PATH: /mnt/ml-data/LibriSpeech/test-clean/4077/13754/4077-13754-0004.wav
# r:rejoice in our presence said the air and the sunlight
# p:we choice and our presence said the air and the sunlight
# 27: WER: 0.0909090909091, DURATION: 4.93, PATH: /mnt/ml-data/LibriSpeech/test-clean/672/122797/672-122797-0018.wav
# r:hakon there shall be your constant companion friend farmer
# p:hawkin there shall be your constantcompanion friend farmer
# 28: WER: 0.042735042735, DURATION: 3.575, PATH: /mnt/ml-data/LibriSpeech/test-clean/5142/33396/5142-33396-0037.wav
# r:embrace him and forget about the nature of god
# p:embrace him and forget about the nature of god
# 29: WER: 0.0, DURATION: 3.42, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0049.wav
# r:but i would not speak at the time because i wanted to refresh my memory
# p:but i would not speak at the time because i wanted to refresh my memory
# 30: WER: 0.0, DURATION: 4.94, PATH: /mnt/ml-data/LibriSpeech/test-clean/2961/961/2961-961-0021.wav
# r:it is founded on the acknowledged weakness of those who survive that period of life at which men cease to work
# p:it is found in on the agknowledge weakness of those who survive that purid of life at which men cseased to work
# 31: WER: 0.0588235294118, DURATION: 7.16, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0058.wav
# r:i refer to the thermometer it indicates the figure is obliterated
# p:i referred to the themometer it in a cates the figure is abliterated
# 32: WER: 0.0827067669173, DURATION: 4.865, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123288/260-123288-0016.wav
# r:he obtained the desired speed and load with a friction brake also regulator of speed but waited for an indicator to verify it
# p:he obtained the desired speed ind load with a fiction break also regulater of speed but waited for it indicator o varify at
# 33: WER: 0.0645161290323, DURATION: 8.875, PATH: /mnt/ml-data/LibriSpeech/test-clean/2300/131720/2300-131720-0015.wav
# r:shall i never miss home talk and blessing and the common kiss that comes to each in turn nor count it strange when i look up to drop on a new range of walls and floors another home than this
# p:shall i never miss home talk and blessing and the common kiss the comes to each in turn nor counted strange when i look up to drop on a new range of walls and floors another home than this
# 34: WER: 0.021164021164, DURATION: 14.755, PATH: /mnt/ml-data/LibriSpeech/test-clean/908/31957/908-31957-0004.wav
# r:his tones rang pleasantly on warrenton's ears and forthwith a good fellowship was heralded between them
# p:his tones ran pleasantly unwarrinton's ears and fourthwith the good fellowship was heralded between them
# 35: WER: 0.0531400966184, DURATION: 5.98, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70970/61-70970-0037.wav
# r:some points may be taken as fixed and such as any theory of memory must arrive at
# p:the some points may retakan outs fixed and such as any theory of memory must arrive at
# 36: WER: 0.0778443113772, DURATION: 6.44, PATH: /mnt/ml-data/LibriSpeech/test-clean/8230/279154/8230-279154-0022.wav
# r:she gathered up her reins
# p:she gathered up herrains
# 37: WER: 0.0612244897959, DURATION: 2.305, PATH: /mnt/ml-data/LibriSpeech/test-clean/237/134493/237-134493-0008.wav
# r:not at all you are on the contrary most agreeable to me
# p:not at all you are on the contrary mostagreeable to me
# 38: WER: 0.00917431192661, DURATION: 4.72, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75946/7127-75946-0009.wav
# r:i now use them as ornamental statuary in my garden
# p:i know use the mazlaramental statue ari and my garden
# 39: WER: 0.184466019417, DURATION: 3.2, PATH: /mnt/ml-data/LibriSpeech/test-clean/1284/1181/1284-1181-0019.wav
# r:above all things i desire to settle the matter quietly and discreetly
# p:above all things i desire to settle the matter quietly anddiscreetly
# 40: WER: 0.00729927007299, DURATION: 4.32, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141083/1580-141083-0013.wav
# r:but what is the delicate mission i asked
# p:but what is the delicate mission  asked
# 41: WER: 0.0126582278481, DURATION: 3.145, PATH: /mnt/ml-data/LibriSpeech/test-clean/8455/210777/8455-210777-0043.wav
# r:sire he said your majesty's most devoted servant approaches to perform a service on this occasion with similar zeal that he has already shown on the field of battle
# p:sire he said your majesty's most devoted servant approaches to perform a service on this occasion with somuler zeal that he is already shown on the field of battle
# 42: WER: 0.0275229357798, DURATION: 10.94, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75946/7127-75946-0022.wav
# r:either he calls ministers through the agency of men or he calls them directly as he called the prophets and apostles
# p:either he calls ministers through the agency of men or recalls them directly as he called the prophets and apostles
# 43: WER: 0.012987012987, DURATION: 6.525, PATH: /mnt/ml-data/LibriSpeech/test-clean/2830/3980/2830-3980-0010.wav
# r:even the supporting cast is shrewdly drawn professor aronnax the career scientist caught in an ethical conflict conseil the compulsive classifier who supplies humorous tag lines for verne's fast facts the harpooner ned land a creature of constant appetites man as heroic animal
# p:even ta supporting cast as shrewdly drawn perofessor an anax the career sientist caught in an ethical conflict consel the compossive classifie who supplies humorous taglines for vern's fast facts the harp booner ned land a creature of constant appetites man as heroic animals
# 44: WER: 0.0434782608696, DURATION: 21.05, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/294825/8463-294825-0007.wav
# r:it is possible that i may be in a position then to indicate some course of action
# p:it is possible that i may be in a position then to indicate some course of action
# 45: WER: 0.00613496932515, DURATION: 4.685, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141084/1580-141084-0009.wav
# r:ah very well
# p:ah very well
# 46: WER: 0.04, DURATION: 2.17, PATH: /mnt/ml-data/LibriSpeech/test-clean/7127/75946/7127-75946-0001.wav
# r:since the period of our tale the active spirit of the country has surrounded it with a belt of rich and thriving settlements though none but the hunter or the savage is ever known even now to penetrate its wild recesses
# p:since the period of our tail the active spirit of the country has surrounded it with a belt of rich and thriving settlements though none but the hunter or the savags ever known even now to penetrate its wild recesses
# 47: WER: 0.016091954023, DURATION: 13.48, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122612/1320-122612-0000.wav
# r:it was simple enough sir if you only had known but with all your cleverness it was impossible that you could know
# p:it was simple enough sir if you only had known but with all your cleverness it was impossible that you could know
# 48: WER: 0.0, DURATION: 7.575, PATH: /mnt/ml-data/LibriSpeech/test-clean/1580/141084/1580-141084-0049.wav
# r:by the by i've never seen your dairy i must see your dairy missus poyser
# p:by the mye i'm never seen your dary i must seer dari missus boycerees
# 49: WER: 0.109489051095, DURATION: 4.93, PATH: /mnt/ml-data/LibriSpeech/test-clean/2094/142345/2094-142345-0058.wav
# r:but hawkeye who was too much occupied with his own thoughts to note the movement continued speaking more to himself than to his companion
# p:but harkey who was too much ocupied with his own thoughts to note the movement continued speaking more to himself into his companion
# 50: WER: 0.0334572490706, DURATION: 7.555, PATH: /mnt/ml-data/LibriSpeech/test-clean/1320/122617/1320-122617-0024.wav
# r:the duchess of southbridge to lord reggie oh reggie what did you say
# p:the duchtes of southbridge to lord reggip ohreggie what did you say
# 51: WER: 0.0518518518519, DURATION: 4.465, PATH: /mnt/ml-data/LibriSpeech/test-clean/7176/92135/7176-92135-0034.wav
# r:can one imagine a naturalist refusing to study the viper the bat the scorpion the centipede the tarantula and one who would cast them back into their darkness saying oh how ugly that is
# p:ten bon imagine an aturalist refusing to study the viber the bad the scorpion the centeppede the turenchilla and one who would cast them back into their darkness saying oh how ugly that is
# 52: WER: 0.0723860589812, DURATION: 17.265, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0016.wav
# r:the count shook his head
# p:the count shook his head
# 53: WER: 0.0204081632653, DURATION: 2.3, PATH: /mnt/ml-data/LibriSpeech/test-clean/5105/28240/5105-28240-0020.wav
# r:i thought we were stumped again when i first saw that picture but it's been of some use after all
# p:i thought we were stumped again when i first saw that berture but it smin of son us after all
# 54: WER: 0.0947368421053, DURATION: 5.185, PATH: /mnt/ml-data/LibriSpeech/test-clean/6930/76324/6930-76324-0008.wav
# r:you see loving some one as i love you makes the whole world different
# p:you see loving someone as i love you mie the whole world different
# 55: WER: 0.0441176470588, DURATION: 4.755, PATH: /mnt/ml-data/LibriSpeech/test-clean/4446/2275/4446-2275-0041.wav
# r:rejoice in thy growth said the sunbeams
# p:rejoice inly growth said the sunbeams
# 56: WER: 0.0649350649351, DURATION: 3.815, PATH: /mnt/ml-data/LibriSpeech/test-clean/672/122797/672-122797-0010.wav
# r:he himself recited the same passage in french and politely pointed out the parts in which he thought that i had improved on the original
# p:he himself recited the same passage in french and politely pointed out the parts in which he thought that i had improved on the original
# 57: WER: 0.0, DURATION: 8.825, PATH: /mnt/ml-data/LibriSpeech/test-clean/3729/6852/3729-6852-0039.wav
# r:you'll never dig it out of the astor library
# p:you'll never dig it out of the aster whibrury
# 58: WER: 0.0786516853933, DURATION: 3.03, PATH: /mnt/ml-data/LibriSpeech/test-clean/4970/29093/4970-29093-0000.wav
# r:true history being a mixture of all things the true historian mingles in everything
# p:to history being a mixture of all things the true historian mingles in everything
# 59: WER: 0.0243902439024, DURATION: 7.535, PATH: /mnt/ml-data/LibriSpeech/test-clean/4507/16021/4507-16021-0035.wav
# r:something better something still grander must follow but what
# p:something better is something still grander must follow but what
# 60: WER: 0.024, DURATION: 4.82, PATH: /mnt/ml-data/LibriSpeech/test-clean/672/122797/672-122797-0017.wav
# r:chapter three as master wishes
# p:chapter three as master wishes
# 61: WER: 0.016393442623, DURATION: 3.615, PATH: /mnt/ml-data/LibriSpeech/test-clean/8463/294828/8463-294828-0000.wav
# r:those clouds seem as if they were going to crush the sea
# p:those cloudseemes if they were going to crush the sea
# 62: WER: 0.045871559633, DURATION: 3.435, PATH: /mnt/ml-data/LibriSpeech/test-clean/260/123288/260-123288-0009.wav
# r:surely we can submit with good grace
# p:surely we can submit with good grace
# 63: WER: 0.0, DURATION: 2.69, PATH: /mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0021.wav
# batch mean WER: 0.0465620024165
# LM WER: 0.048785578606 No LM WER: 0.0508996571184

# %%
print '\n'.join(['{s} {p}'.format(s=e[0], p=e[1]) for e in zip(*beam_decode_u(res[0][:, 49, :], 8))])
# Out:
# ulme letmteaebh es ra pe c heo knsn 169.558395386
# ulme letmteaebh es ra pe c eo knsn 169.513000488
# ulme letmteaebh es rae pe c heo knsn 169.449188232
# ulme letmteaebh es rae pe c eo knsn 169.403793335
# ulme letmteaebh s ra pe c heo knsn 169.402740479
# ultme letmteaebh es ra pe c heo knsn 169.377624512
# ulme letmteaebh es ra pe c heo ksn 169.311843872
# ulme letmteaebh es ra pe c eo ksn 169.266448975

# %%
print '\n'.join(['{s} {p}'.format(s=e[0], p=e[1]) for e in zip(*beam_decode_u(res[0][:, 49, :], 20, eps=.5, normalize=True))])
# Out:
# oh little cloud the vertun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.984375
# oh little cloud the virtun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.9765625
# oh little cloud the vertin said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.9257812
# oh little cloud the virtin said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.9160156
# oh little cloud the vertun said i charge thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.7851562
# oh little cloud the virtun said i charge thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.7753906
# oh little cloud the vertun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like to thee 16591.7324219
# oh little cloud the vertin said i charge thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.7265625
# oh little cloud the virtun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like to thee 16591.7226562
# oh little cloud the virtin said i charge thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.7167969
# ah little cloud the vertun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.6816406
# ah little cloud the virtun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty thee 16591.6738281
# oh little cloud the vertin said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like to thee 16591.671875
# oh little cloud the virtin said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like to thee 16591.6640625
# oh little cloud the vertun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty theee 16580.9140625
# oh little cloud the virtun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty theee 16580.90625
# oh little cloud the vertin said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty theee 16580.8554688
# oh little cloud the virtin said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty theee 16580.8457031
# oh little cloud the vertun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty theed 16578.890625
# oh little cloud the virtun said i charged thee to tell me why thou complain is now when in one hour thou fataway then we shall seek thee but not fine ah fell as like ty theed 16578.8828125

# %%
print '\n'.join(['{s} {p}'.format(s=e[0], p=e[1]) for e in zip(*beam_decode_u(res[0][:, 1, :], 20, normalize=True))])
# Out:
# ah the swab the cruel squart 12610.1259766
# ah the swab the qruel squart 12609.7929688
# ah the swab the cruel squar 12609.7626953
# ah the swam the cruel squart 12609.5244141
# ah the swab the cruel squarp 12609.5
# ah the swab the qruel squar 12609.4296875
# ah the swab the cruel swuart 12609.3925781
# ah the swab othe cruel squart 12609.2734375
# ah the swam the qruel squart 12609.1914062
# ah the swab the cruel squant 12609.1806641
# ah the swab the qruel squarp 12609.1669922
# ah the swam the cruel squar 12609.1601562
# ah the swab the cruel squamt 12609.1191406
# ah the swab the qruel swuart 12609.0595703
# ah the swab the cruel swuar 12609.0283203
# ah the swap the cruel squart 12608.9619141
# ah the swab othe qruel squart 12608.9404297
# ah the swab othe cruel squar 12608.9101562
# ah the swab the cruel squat 12608.9101562
# ah the swam the cruel squarp 12608.8984375

# %%
for i in range(1, 100000, 1000):
    eps = 1000 / i
    preds = [e[0] for e in zip(*beam_decode_u(res[0][:, 1, :], 20, normalize=True)) if 'swamp' in e[0]]
    if preds:
        print preds, eps

# %%
res[0][1].min()
# Out:
# -11.001603

# %%
import beamsearch
reload(beamsearch)
from beamsearch import beam_decode_u

# %%
# thus idleness is the mother
# thus i don't lissisthe mother
def edits(word):
    letters = ''.join([chr(i) for i in range(ord('a'), ord('z') + 1)])
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l, r in splits if r]
    transposes = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r) >1]
    replaces = [l + c + r[1:] for c in letters for l, r in splits if r]
    inserts = [l + c + r for c in letters for l, r in splits if r]
    return set(deletes + transposes + replaces + inserts)

def edits_n(word, n):
    es = set([word])
    for i in range(n):
        es = reduce(lambda a, b: a.union(b), (edits(w) for w in es))
    return es

def words(text):
    return text.split()

def known_words(words):
    return {word for word in words if word in WORDS}

def candidate_words(word):
    return (known_words([word]) or known_words(edits_n(word, 1)) or known_words(edits_n(word, 2)) or [word])

list(candidate_words("swam"))
# Out:
# ['swam']

# %%
with open('./data/lm/words.txt') as f:
    WORDS = set(words(f.read()))

# %%
r:a ring of amethyst i could not wear here plainer to my sight than that first kiss
p:a ring of amathyst i could not wear here plainer two my sight then that first kits

# %%
best_lm_alternative(res[3][3], res[2][3], zip(*beam_decode_u(res[0][:, 3, :], 12, normalize=True)))
# Out:
# she doesn't take up with anybody you know
# she doesn't take up with anybody you know
# langauge model changed prediction, WER changed from 0.0243902439024 to 0.0
# "she doesn't take up with anybody you know"

# %%
print best_lm_alternative(res[3][46], res[2][46], zip(*beam_decode_u(res[0][:, 46, :], 12, normalize=False)))
print res[1][46]
# Out:
# sir i have it in command to inform your excellency that you have been appointed governor of the crown colony which is called britannula
# sir i have in command to anform your excellency that you have been appointed governor of the crown colony which is called britain mula
# langauge model changed prediction, WER changed from 0.0334572490706 to 0.0334572490706
# sir i have in command to anform your excellency that you have been appointed governor of the crown colony which is called britain mula
# sir i have in command to anform your excellency that you have been appointed governor of the crown colony which is called britaan mula

# %%
import edit_distance
ref = 'there is no danger of the modern commentators on the timaeus falling into the absurdities of the neo platonists'
pre = 'there is old danger of the madern commontychers un ther to meas falling into dubsurdities of the newo platinists'
pre = 'there is old danger of the madern commontychers un ther to mes falling into dubsurdities of the newo platinists'
#print edit_distance.SequenceMatcher(ref, pre).ratio()
word_error_rate([ref], [pre], decoded=True)[0]
# Out:
# 0.16216216216216217

# %% [markdown]
# #### custom samples

# %%
samples = [
    {"duration": 4.905, "text": "he began a confused complaint against the wizard who had vanished behind the curtain on the left", "key": "/mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0000.wav"},
    {"duration": 3.61, "text": "give not so earnest a mind to these mummeries child", "key": "/mnt/ml-data/LibriSpeech/test-clean/61/70968/61-70968-0001.wav"}    
]

# %%
evaluate(test_generator(datagen, samples, normalize=True), output_fn)
